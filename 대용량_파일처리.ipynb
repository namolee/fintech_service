# %% [markdown]
# ## 1. 전국 아파트 매매 데이터 1999-2024 합치기
# ## 2. database에서 1999-2024 USD 환율정보 가져와 합치기
# ## 3. 전국 학원 정보 가져와서 합치기(시군구 단위)
# ## 4. 금리 정보 합치기
# ## 5. 회귀분석으로 집값 예측하기

# %%
import pandas as pd
import numpy as np
import glob

# %%
import pandas as pd
import glob

# 파일 경로 설정
path = './mini_project/아파트매매실거래가1999-202408/*.csv'  # 해당 폴더에 있는 모든 csv 파일을 선택
all_files = glob.glob(path)

# 모든 파일을 읽어 하나의 리스트에 저장
li = []

for filename in all_files:
    df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949', 
                     skiprows=15)  # 처음 15줄을 건너뛰고 16번째 줄부터 읽기
    li.append(df)

# 리스트에 저장된 모든 데이터프레임을 하나로 합치기
apt_data = pd.concat(li, axis=0, ignore_index=True)

# 결과 확인
print(apt_data)
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:12: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(filename, index_col=None, header=0, encoding='cp949',
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\703423259.py:17: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   apt_data = pd.concat(li, axis=0, ignore_index=True)
#                          시군구      번지    본번   부번        단지명   전용면적(㎡)    계약년월  \
# 0         강원특별자치도 양구군 양구읍 상리     510   510  0.0         경림   59.4000  200509
# 1               경기도 의정부시 민락동   756-7   756  7.0      한라비발디   84.9900  200510
# 2               경기도 의정부시 신곡동     456   456  0.0        신일1   59.8780  200510
# 3               경기도 의정부시 신곡동   727-1   727  1.0         풍림   49.8300  200510
# 4               경기도 의정부시 용현동      46    46  0.0     용현현대1차  129.7300  200511
# ...                      ...     ...   ...  ...        ...       ...     ...
# 10041446        인천광역시 서구 당하동  1090-1  1090  1.0  검단힐스테이트4차  107.4423  202408
# 10041447     경기도 수원시 권선구 세류동    1255  1255  0.0      권선어울림  120.4100  202408
# 10041448   울산광역시 울주군 온양읍 망양리   가-5-1     5  1.0       회야리버   39.7150  202408
# 10041449        대전광역시 서구 둔산동    1510  1510  0.0         목련  101.8300  202408
# 10041450        인천광역시 서구 마전동     925   925  0.0         서해   59.9700  202408
#
#          계약일 거래금액(만원)   층  ...           도로명 해제사유발생일 등기신청일자  거래유형      중개사소재지  \
# 0         23    5,000  11  ...    양록길23번길 11     NaN            -           -
# 1         30   12,750  19  ...        오목로 73     NaN            -           -
# 2         20    5,750   3  ...   시민로245번길 10     NaN            -           -
# 3         20    5,500   8  ...       회룡로 245     NaN            -           -
# 4         21   12,200  11  ...        오목로 36     NaN            -           -
# ...       ..      ...  ..  ...           ...     ...    ...   ...         ...
# 10041446   1   52,000   8  ...        청마로 92       -    NaN  중개거래       인천 서구
# 10041447   1   58,800   9  ...  세권로43번길 26-6       -    NaN  중개거래  경기 수원시 권선구
# 10041448   1    7,000   4  ...     원동2길 19-2       -    NaN   직거래           -
# 10041449   1   98,500   1  ...      둔산남로 127       -    NaN  중개거래       대전 서구
# 10041450   1   15,800   2  ...  검단로487번안길 16       -    NaN  중개거래       인천 서구
#
#                NO    동  매수자  매도자      등기일자
# 0             NaN  NaN  NaN  NaN       NaN
# 1             NaN  NaN  NaN  NaN       NaN
# 2             NaN  NaN  NaN  NaN       NaN
# 3             NaN  NaN  NaN  NaN       NaN
# 4             NaN  NaN  NaN  NaN       NaN
# ...           ...  ...  ...  ...       ...
# 10041446  41073.0    -   개인   개인         -
# 10041447  41074.0    -   개인   개인         -
# 10041448  41075.0  101   개인   개인  24.08.02
# 10041449  41076.0    -   개인   개인         -
# 10041450  41077.0    -   개인   개인         -
#
# [10041451 rows x 21 columns]

# %%
apt_data.head()
# Out:
#                   시군구     번지   본번   부번     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)  \
# 0  강원특별자치도 양구군 양구읍 상리    510  510  0.0      경림   59.400  200509  23    5,000
# 1        경기도 의정부시 민락동  756-7  756  7.0   한라비발디   84.990  200510  30   12,750
# 2        경기도 의정부시 신곡동    456  456  0.0     신일1   59.878  200510  20    5,750
# 3        경기도 의정부시 신곡동  727-1  727  1.0      풍림   49.830  200510  20    5,500
# 4        경기도 의정부시 용현동     46   46  0.0  용현현대1차  129.730  200511  21   12,200
#
#     층  ...          도로명 해제사유발생일 등기신청일자 거래유형 중개사소재지  NO    동  매수자  매도자 등기일자
# 0  11  ...   양록길23번길 11     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 1  19  ...       오목로 73     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 2   3  ...  시민로245번길 10     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 3   8  ...      회룡로 245     NaN           -      - NaN  NaN  NaN  NaN  NaN
# 4  11  ...       오목로 36     NaN           -      - NaN  NaN  NaN  NaN  NaN
#
# [5 rows x 21 columns]

# %%
apt_data
# Out:
#                          시군구      번지    본번   부번        단지명   전용면적(㎡)    계약년월  \
# 0         강원특별자치도 양구군 양구읍 상리     510   510  0.0         경림   59.4000  200509
# 1               경기도 의정부시 민락동   756-7   756  7.0      한라비발디   84.9900  200510
# 2               경기도 의정부시 신곡동     456   456  0.0        신일1   59.8780  200510
# 3               경기도 의정부시 신곡동   727-1   727  1.0         풍림   49.8300  200510
# 4               경기도 의정부시 용현동      46    46  0.0     용현현대1차  129.7300  200511
# ...                      ...     ...   ...  ...        ...       ...     ...
# 10041446        인천광역시 서구 당하동  1090-1  1090  1.0  검단힐스테이트4차  107.4423  202408
# 10041447     경기도 수원시 권선구 세류동    1255  1255  0.0      권선어울림  120.4100  202408
# 10041448   울산광역시 울주군 온양읍 망양리   가-5-1     5  1.0       회야리버   39.7150  202408
# 10041449        대전광역시 서구 둔산동    1510  1510  0.0         목련  101.8300  202408
# 10041450        인천광역시 서구 마전동     925   925  0.0         서해   59.9700  202408
#
#          계약일 거래금액(만원)   층  ...           도로명 해제사유발생일 등기신청일자  거래유형      중개사소재지  \
# 0         23    5,000  11  ...    양록길23번길 11     NaN            -           -
# 1         30   12,750  19  ...        오목로 73     NaN            -           -
# 2         20    5,750   3  ...   시민로245번길 10     NaN            -           -
# 3         20    5,500   8  ...       회룡로 245     NaN            -           -
# 4         21   12,200  11  ...        오목로 36     NaN            -           -
# ...       ..      ...  ..  ...           ...     ...    ...   ...         ...
# 10041446   1   52,000   8  ...        청마로 92       -    NaN  중개거래       인천 서구
# 10041447   1   58,800   9  ...  세권로43번길 26-6       -    NaN  중개거래  경기 수원시 권선구
# 10041448   1    7,000   4  ...     원동2길 19-2       -    NaN   직거래           -
# 10041449   1   98,500   1  ...      둔산남로 127       -    NaN  중개거래       대전 서구
# 10041450   1   15,800   2  ...  검단로487번안길 16       -    NaN  중개거래       인천 서구
#
#                NO    동  매수자  매도자      등기일자
# 0             NaN  NaN  NaN  NaN       NaN
# 1             NaN  NaN  NaN  NaN       NaN
# 2             NaN  NaN  NaN  NaN       NaN
# 3             NaN  NaN  NaN  NaN       NaN
# 4             NaN  NaN  NaN  NaN       NaN
# ...           ...  ...  ...  ...       ...
# 10041446  41073.0    -   개인   개인         -
# 10041447  41074.0    -   개인   개인         -
# 10041448  41075.0  101   개인   개인  24.08.02
# 10041449  41076.0    -   개인   개인         -
# 10041450  41077.0    -   개인   개인         -
#
# [10041451 rows x 21 columns]

# %%
apt_data.columns
# Out:
# Index(['시군구', '번지', '본번', '부번', '단지명', '전용면적(㎡)', '계약년월', '계약일', '거래금액(만원)',
#        '층', '건축년도', '도로명', '해제사유발생일', '등기신청일자', '거래유형', '중개사소재지', 'NO', '동',
#        '매수자', '매도자', '등기일자'],
#       dtype='object')

# %%
apt_data_original = apt_data.copy()

# %%
apt_data=apt_data[['시군구','단지명','전용면적(㎡)','계약년월', '계약일','거래금액(만원)','층','건축년도']]

# %%
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 2        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 3        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0

# %%
apt_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10041451 entries, 0 to 10041450
# Data columns (total 8 columns):
#  #   Column    Dtype
# ---  ------    -----
#  0   시군구       object
#  1   단지명       object
#  2   전용면적(㎡)   float64
#  3   계약년월      object
#  4   계약일       object
#  5   거래금액(만원)  object
#  6   층         object
#  7   건축년도      float64
# dtypes: float64(2), object(6)
# memory usage: 612.9+ MB

# %%
type(apt_data['계약년월'][0])
# Out:
# int

# %%
# 계약년월과 계약일을 문자열로 변환
apt_data['계약년월'] = apt_data['계약년월'].astype(str)
apt_data['계약일'] = apt_data['계약일'].astype(str)

# 계약년월 컬럼의 년도와 월을 분리하고, 계약일을 두 자리 수로 포맷팅
apt_data['년도'] = apt_data['계약년월'].str.slice(0, 4)
apt_data['월'] = apt_data['계약년월'].str.slice(4, 6)
apt_data['일'] = apt_data['계약일'].apply(lambda x: f"{int(x):02d}")

# 새로운 계약날짜 컬럼 생성
apt_data['계약날짜'] = apt_data['년도'] + '-' + apt_data['월'] + '-' + apt_data['일']

# 필요없는 임시 컬럼 삭제
apt_data.drop(columns=['년도', '월', '일'], inplace=True)

# 결과 확인
print(apt_data[['계약날짜']].head())
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['계약년월'] = apt_data['계약년월'].astype(str)
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['계약일'] = apt_data['계약일'].astype(str)
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['년도'] = apt_data['계약년월'].str.slice(0, 4)
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['월'] = apt_data['계약년월'].str.slice(4, 6)
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['일'] = apt_data['계약일'].apply(lambda x: f"{int(x):02d}")
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['계약날짜'] = apt_data['년도'] + '-' + apt_data['월'] + '-' + apt_data['일']
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\85726809.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data.drop(columns=['년도', '월', '일'], inplace=True)
#          계약날짜
# 0  2005-09-23
# 1  2005-10-30
# 2  2005-10-20
# 3  2005-10-20
# 4  2005-11-21

# %%
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 2        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 3        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#          계약날짜
# 0  2005-09-23
# 1  2005-10-30
# 2  2005-10-20
# 3  2005-10-20
# 4  2005-11-21

# %% [markdown]
# ### 금리 데이터 가져오기

# %%
interest_data = pd.read_csv("./mini_project/기준금리1999-2023.csv")
interest_data
# Out:
#     변경일자 Unnamed: 1  기준금리
# 0   2023    01월 13일  3.50
# 1   2022    11월 24일  3.25
# 2   2022    10월 12일  3.00
# 3   2022    08월 25일  2.50
# 4   2022    07월 13일  2.25
# 5   2022    05월 26일  1.75
# 6   2022    04월 14일  1.50
# 7   2022    01월 14일  1.25
# 8   2021    11월 25일  1.00
# 9   2021    08월 26일  0.75
# 10  2020    05월 28일  0.50
# 11  2020    03월 17일  0.75
# 12  2019    10월 16일  1.25
# 13  2019    07월 18일  1.50
# 14  2018    11월 30일  1.75
# 15  2017    11월 30일  1.50
# 16  2016    06월 09일  1.25
# 17  2015    06월 11일  1.50
# 18  2015    03월 12일  1.75
# 19  2014    10월 15일  2.00
# 20  2014    08월 14일  2.25
# 21  2013    05월 09일  2.50
# 22  2012    10월 11일  2.75
# 23  2012    07월 12일  3.00
# 24  2011    06월 10일  3.25
# 25  2011    03월 10일  3.00
# 26  2011    01월 13일  2.75
# 27  2010    11월 16일  2.50
# 28  2010    07월 09일  2.25
# 29  2009    02월 12일  2.00
# 30  2009    01월 09일  2.50
# 31  2008    12월 11일  3.00
# 32  2008    11월 07일  4.00
# 33  2008    10월 27일  4.25
# 34  2008    10월 09일  5.00
# 35  2008    08월 07일  5.25
# 36  2007    08월 09일  5.00
# 37  2007    07월 12일  4.75
# 38  2006    08월 10일  4.50
# 39  2006    06월 08일  4.25
# 40  2006    02월 09일  4.00
# 41  2005    12월 08일  3.75
# 42  2005    10월 11일  3.50
# 43  2004    11월 11일  3.25
# 44  2004    08월 12일  3.50
# 45  2003    07월 10일  3.75
# 46  2003    05월 13일  4.00
# 47  2002    05월 07일  4.25
# 48  2001    09월 19일  4.00
# 49  2001    08월 09일  4.50
# 50  2001    07월 05일  4.75
# 51  2001    02월 08일  5.00
# 52  2000    10월 05일  5.25
# 53  2000    02월 10일  5.00
# 54  1999    05월 06일  4.75

# %%
# 변경일자와 Unnamed: 1 컬럼을 문자열로 변환하여 합치기
interest_data['변경일자'] = interest_data['변경일자'].astype(str)
interest_data['Unnamed: 1'] = interest_data['Unnamed: 1'].str.replace(' ', '')  # 공백 제거

# 변경일자와 월일 데이터를 합쳐서 새로운 '변경날짜' 컬럼 생성
interest_data['변경날짜'] = interest_data['변경일자'] + '-' + interest_data['Unnamed: 1']

# 문자열을 날짜 형식으로 변환
interest_data['변경날짜'] = pd.to_datetime(interest_data['변경날짜'], format='%Y-%m월%d일')

# 결과 확인
print(interest_data[['변경날짜']].head())
# Out:
#         변경날짜
# 0 2023-01-13
# 1 2022-11-24
# 2 2022-10-12
# 3 2022-08-25
# 4 2022-07-13

# %%
interest_data.head()
# Out:
#    변경일자 Unnamed: 1  기준금리       변경날짜
# 0  2023     01월13일  3.50 2023-01-13
# 1  2022     11월24일  3.25 2022-11-24
# 2  2022     10월12일  3.00 2022-10-12
# 3  2022     08월25일  2.50 2022-08-25
# 4  2022     07월13일  2.25 2022-07-13

# %%
interest_data = interest_data[['변경날짜', '기준금리']]

# %%
interest_data.head()
# Out:
#         변경날짜  기준금리
# 0 2023-01-13  3.50
# 1 2022-11-24  3.25
# 2 2022-10-12  3.00
# 3 2022-08-25  2.50
# 4 2022-07-13  2.25

# %%
# 계약날짜와 변경날짜의 타입이 datetime으로 되어 있는지 확인하고, 필요시 변환
apt_data['계약날짜'] = pd.to_datetime(apt_data['계약날짜'])
interest_data['변경날짜'] = pd.to_datetime(interest_data['변경날짜'])

# 기준금리를 계약날짜에 맞춰서 apt_data에 추가 (가장 가까운 과거 기준금리 매칭)
apt_data = pd.merge_asof(apt_data.sort_values('계약날짜'),
                         interest_data.sort_values('변경날짜'),
                         left_on='계약날짜',
                         right_on='변경날짜',
                         direction='backward')

# 결과 확인
apt_data.head()
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\2049715228.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   apt_data['계약날짜'] = pd.to_datetime(apt_data['계약날짜'])
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\2049715228.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   interest_data['변경날짜'] = pd.to_datetime(interest_data['변경날짜'])
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리
# 0 2005-09-23 2004-11-11  3.25
# 1 2005-10-20 2005-10-11  3.50
# 2 2005-10-20 2005-10-11  3.50
# 3 2005-10-30 2005-10-11  3.50
# 4 2005-11-21 2005-10-11  3.50

# %%
# Out:
# 0

# %%
# apt_data의 시군구에서 앞 3글자를 추출
apt_data['지역코드'] = apt_data['시군구'].str[:3]

# 지역에 따른 시도교육청명을 매칭하는 함수 정의
def get_education_office(region):
    if '서울' in region:
        return '서울특별시교육청'
    elif '부산' in region:
        return '부산광역시교육청'
    elif '대구' in region:
        return '대구광역시교육청'
    elif '인천' in region:
        return '인천광역시교육청'
    elif '광주' in region:
        return '광주광역시교육청'
    elif '대전' in region:
        return '대전광역시교육청'
    elif '울산' in region:
        return '울산광역시교육청'
    elif '세종' in region:
        return '세종특별자치시교육청'
    elif '경기' in region:
        return '경기도교육청'
    elif '강원' in region:
        return '강원특별자치도교육청'
    elif '충청북' in region:
        return '충청북도교육청'
    elif '충청남' in region:
        return '충청남도교육청'
    elif '전북' in region or '전라북' in region:
        return '전북특별자치도교육청'
    elif '전라남' in region:
        return '전라남도교육청'
    elif '경상북' in region:
        return '경상북도교육청'
    elif '경상남' in region:
        return '경상남도교육청'
    elif '제주' in region:
        return '제주특별자치도교육청'
    else:
        return None

# 시도교육청명 컬럼 추가
apt_data['시도교육청명'] = apt_data['지역코드'].apply(get_education_office)

# 지역코드 컬럼 제거 (필요시)
apt_data.drop(columns=['지역코드'], inplace=True)

# 결과 확인
print(apt_data[['시군구', '시도교육청명']].head())
# Out:
#                   시군구      시도교육청명
# 0  강원특별자치도 양구군 양구읍 상리  강원특별자치도교육청
# 1        경기도 의정부시 신곡동      경기도교육청
# 2        경기도 의정부시 신곡동      경기도교육청
# 3        경기도 의정부시 민락동      경기도교육청
# 4        경기도 의정부시 용현동      경기도교육청

# %%
apt_data['시도교육청명'].isnull().sum()
# Out:
# 0

# %%
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리   학원수      시도교육청명
# 0 2005-09-23 2004-11-11  3.25    24  강원특별자치도교육청
# 1 2005-10-20 2005-10-11  3.50  1151      경기도교육청
# 2 2005-10-20 2005-10-11  3.50  1151      경기도교육청
# 3 2005-10-30 2005-10-11  3.50  1151      경기도교육청
# 4 2005-11-21 2005-10-11  3.50  1151      경기도교육청

# %%
apt_data = apt_data.drop(columns=['학원수'])
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리      시도교육청명
# 0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청
# 1 2005-10-20 2005-10-11  3.50      경기도교육청
# 2 2005-10-20 2005-10-11  3.50      경기도교육청
# 3 2005-10-30 2005-10-11  3.50      경기도교육청
# 4 2005-11-21 2005-10-11  3.50      경기도교육청

# %%
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리      시도교육청명
# 0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청
# 1 2005-10-20 2005-10-11  3.50      경기도교육청
# 2 2005-10-20 2005-10-11  3.50      경기도교육청
# 3 2005-10-30 2005-10-11  3.50      경기도교육청
# 4 2005-11-21 2005-10-11  3.50      경기도교육청

# %%
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리      시도교육청명 행정구역명
# 0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청   양구군
# 1 2005-10-20 2005-10-11  3.50      경기도교육청   NaN
# 2 2005-10-20 2005-10-11  3.50      경기도교육청   NaN
# 3 2005-10-30 2005-10-11  3.50      경기도교육청   NaN
# 4 2005-11-21 2005-10-11  3.50      경기도교육청   NaN

# %% [markdown]
# ## 학원 데이터 불러오기

# %%
# cp949 인코딩으로 파일 읽기
academy_data = pd.read_csv("./mini_project/학원교습소정보_2024년08월31일기준.csv", encoding='cp949')
academy_data.head()
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\1524050090.py:2: DtypeWarning: Columns (6,22) have mixed types. Specify dtype option on import or set low_memory=False.
#   academy_data = pd.read_csv("./mini_project/학원교습소정보_2024년08월31일기준.csv", encoding='cp949')
#   시도교육청코드    시도교육청명 행정구역명 학원교습소구분명      학원지정번호                     학원명  \
# 0     B10  서울특별시교육청   강남구       학원  3000040160                    대치학원
# 1     B10  서울특별시교육청   강남구       학원  3000039285      (A STUDIO)에이스튜디오학원
# 2     B10  서울특별시교육청   강남구       학원        2531            (주)멘토르수학전문학원
# 3     B10  서울특별시교육청   강남구       학원  3000012704     (주)산에듀김영준국어논술전문별관학원
# 4     B10  서울특별시교육청   강남구       학원  3000043003  (주)산에듀김영준국어논술전문프리미엄관학원
#
#        개설일자      등록일자 등록상태명    휴원시작일자  ... 교습과정목록명           교습과정명  인당수강료내용  \
# 0  20211111  20211111    개원            ...   보습·논술           보습·논술
# 1  20210630  20210630    개원            ...     NaN  연기(연극,뮤지컬,오페라)
# 2  19950804  19950804    개원            ...     보습,              보습
# 3  20110415  20110415    개원            ...   보습·논술           보습·논술
# 4  20221230  20221230    개원            ...   보습·논술           보습·논술
#
#   수강료공개여부 기숙사학원여부                시설도로명주소                시설도로명상세주소 시설도로명우편번호  \
# 0       Y       N      서울특별시 강남구 삼성로 347       , 201호 (대치동, 대일빌딩)      6202
# 1       Y       N    서울특별시 강남구 논현로134길 5           , 5층, 6층 (논현동)      6052
# 2       N       N   서울특별시 강남구 남부순환로 2927  , 501호 일부(대치동, 대치 클래시아)      6280
# 3       N       N    서울특별시 강남구 선릉로62길 27             , 1~4층 (대치동)    135998
# 4       Y       N  서울특별시 강남구 선릉로62길 32-2         , 5층 (대치동, 대아빌딩)      6207
#
#            전화번호      수정일자
# 0  02-2135-7135  20240908
# 1  02-6013-8112  20231018
# 2   02-564-5002  20240428
# 3   02-501-0575  20240908
# 4           NaN  20240908
#
# [5 rows x 25 columns]

# %%
academy_data['시도교육청명'].unique()
# Out:
# array(['서울특별시교육청', '부산광역시교육청', '대구광역시교육청', '인천광역시교육청', '광주광역시교육청',
#        '대전광역시교육청', '울산광역시교육청', '세종특별자치시교육청', '경기도교육청', '강원특별자치도교육청',
#        '충청북도교육청', '충청남도교육청', '전북특별자치도교육청', '전라북도교육청', '전라남도교육청',
#        '경상북도교육청', '경상남도교육청', '제주특별자치도교육청'], dtype=object)

# %%
# '전라북도교육청'을 '전북특별자치도교육청'으로 변경
academy_data['시도교육청명'] = academy_data['시도교육청명'].replace('전라북도교육청', '전북특별자치도교육청')

# 결과 확인
print(academy_data['시도교육청명'].unique())  # 변경된 값이 반영되었는지 확인
# Out:
# ['서울특별시교육청' '부산광역시교육청' '대구광역시교육청' '인천광역시교육청' '광주광역시교육청' '대전광역시교육청'
#  '울산광역시교육청' '세종특별자치시교육청' '경기도교육청' '강원특별자치도교육청' '충청북도교육청' '충청남도교육청'
#  '전북특별자치도교육청' '전라남도교육청' '경상북도교육청' '경상남도교육청' '제주특별자치도교육청']

# %%
academy_data.head()
# Out:
#   시도교육청코드    시도교육청명 행정구역명 학원교습소구분명      학원지정번호                     학원명  \
# 0     B10  서울특별시교육청   강남구       학원  3000040160                    대치학원
# 1     B10  서울특별시교육청   강남구       학원  3000039285      (A STUDIO)에이스튜디오학원
# 2     B10  서울특별시교육청   강남구       학원        2531            (주)멘토르수학전문학원
# 3     B10  서울특별시교육청   강남구       학원  3000012704     (주)산에듀김영준국어논술전문별관학원
# 4     B10  서울특별시교육청   강남구       학원  3000043003  (주)산에듀김영준국어논술전문프리미엄관학원
#
#        개설일자      등록일자 등록상태명    휴원시작일자  ... 교습과정목록명           교습과정명  인당수강료내용  \
# 0  20211111  20211111    개원            ...   보습·논술           보습·논술
# 1  20210630  20210630    개원            ...     NaN  연기(연극,뮤지컬,오페라)
# 2  19950804  19950804    개원            ...     보습,              보습
# 3  20110415  20110415    개원            ...   보습·논술           보습·논술
# 4  20221230  20221230    개원            ...   보습·논술           보습·논술
#
#   수강료공개여부 기숙사학원여부                시설도로명주소                시설도로명상세주소 시설도로명우편번호  \
# 0       Y       N      서울특별시 강남구 삼성로 347       , 201호 (대치동, 대일빌딩)      6202
# 1       Y       N    서울특별시 강남구 논현로134길 5           , 5층, 6층 (논현동)      6052
# 2       N       N   서울특별시 강남구 남부순환로 2927  , 501호 일부(대치동, 대치 클래시아)      6280
# 3       N       N    서울특별시 강남구 선릉로62길 27             , 1~4층 (대치동)    135998
# 4       Y       N  서울특별시 강남구 선릉로62길 32-2         , 5층 (대치동, 대아빌딩)      6207
#
#            전화번호      수정일자
# 0  02-2135-7135  20240908
# 1  02-6013-8112  20231018
# 2   02-564-5002  20240428
# 3   02-501-0575  20240908
# 4           NaN  20240908
#
# [5 rows x 25 columns]

# %%
# 1. academy_data에서 시도교육청명과 행정구역명별 학원 수 계산
academy_counts = academy_data.groupby(['시도교육청명', '행정구역명']).size().reset_index(name='학원수')

# 2. apt_data에 학원수 컬럼을 기본값 None으로 설정
apt_data['학원수'] = None

# 3. 벡터화된 방식으로 행정구역명이 시군구에 포함되어 있는지 확인
for i, region_row in academy_counts.iterrows():
    # 시군구에 해당 행정구역명이 포함되어 있고, 시도교육청명도 일치하는지 확인
    mask = (apt_data['시도교육청명'] == region_row['시도교육청명']) & apt_data['시군구'].str.contains(region_row['행정구역명'])
    # 해당하는 행에 학원수 추가
    apt_data.loc[mask, '학원수'] = region_row['학원수']

# 결과 확인
print(apt_data[['시군구', '학원수', '시도교육청명']].head())
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\3649068088.py:10: UserWarning: This pattern is interpreted as a regular expression, and has match groups. To actually get the groups, use str.extract.
#   mask = (apt_data['시도교육청명'] == region_row['시도교육청명']) & apt_data['시군구'].str.contains(region_row['행정구역명'])
#                   시군구   학원수      시도교육청명
# 0  강원특별자치도 양구군 양구읍 상리    24  강원특별자치도교육청
# 1        경기도 의정부시 신곡동  1151      경기도교육청
# 2        경기도 의정부시 신곡동  1151      경기도교육청
# 3        경기도 의정부시 민락동  1151      경기도교육청
# 4        경기도 의정부시 용현동  1151      경기도교육청

# %%
apt_data.head()
# Out:
#                   시군구     단지명  전용면적(㎡)    계약년월 계약일 거래금액(만원)   층    건축년도  \
# 0  강원특별자치도 양구군 양구읍 상리      경림   59.400  200509  23    5,000  11  1998.0
# 1        경기도 의정부시 신곡동     신일1   59.878  200510  20    5,750   3  1997.0
# 2        경기도 의정부시 신곡동      풍림   49.830  200510  20    5,500   8  1998.0
# 3        경기도 의정부시 민락동   한라비발디   84.990  200510  30   12,750  19  2003.0
# 4        경기도 의정부시 용현동  용현현대1차  129.730  200511  21   12,200  11  1992.0
#
#         계약날짜       변경날짜  기준금리      시도교육청명   학원수
# 0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청    24
# 1 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 2 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 3 2005-10-30 2005-10-11  3.50      경기도교육청  1151
# 4 2005-11-21 2005-10-11  3.50      경기도교육청  1151

# %%
apt_data
# Out:
#                          시군구            단지명   전용면적(㎡)    계약년월 계약일 거래금액(만원)  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000  200509  23    5,000
# 1               경기도 의정부시 신곡동            신일1   59.8780  200510  20    5,750
# 2               경기도 의정부시 신곡동             풍림   49.8300  200510  20    5,500
# 3               경기도 의정부시 민락동          한라비발디   84.9900  200510  30   12,750
# 4               경기도 의정부시 용현동         용현현대1차  129.7300  200511  21   12,200
# ...                      ...            ...       ...     ...  ..      ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700  202408  31    3,000
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457  202408  31   52,000
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800  202408  31    4,700
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990  202408  31   34,200
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896  202408  31   20,900
#
#            층    건축년도       계약날짜       변경날짜  기준금리      시도교육청명   학원수
# 0         11  1998.0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청    24
# 1          3  1997.0 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 2          8  1998.0 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 3         19  2003.0 2005-10-30 2005-10-11  3.50      경기도교육청  1151
# 4         11  1992.0 2005-11-21 2005-10-11  3.50      경기도교육청  1151
# ...       ..     ...        ...        ...   ...         ...   ...
# 10041446   5  1992.0 2024-08-31 2023-01-13  3.50     충청남도교육청   363
# 10041447   7  2017.0 2024-08-31 2023-01-13  3.50     경상북도교육청   390
# 10041448   1  1999.0 2024-08-31 2023-01-13  3.50     경상북도교육청  1275
# 10041449  15  2017.0 2024-08-31 2023-01-13  3.50     경상남도교육청   928
# 10041450  15  2016.0 2024-08-31 2023-01-13  3.50  전북특별자치도교육청   137
#
# [10041451 rows x 13 columns]

# %%
apt_data
# Out:
#                          시군구            단지명   전용면적(㎡)    계약년월 계약일 거래금액(만원)  \
# 0         강원특별자치도 양구군 양구읍 상리             경림   59.4000  200509  23    5,000
# 1               경기도 의정부시 신곡동            신일1   59.8780  200510  20    5,750
# 2               경기도 의정부시 신곡동             풍림   49.8300  200510  20    5,500
# 3               경기도 의정부시 민락동          한라비발디   84.9900  200510  30   12,750
# 4               경기도 의정부시 용현동         용현현대1차  129.7300  200511  21   12,200
# ...                      ...            ...       ...     ...  ..      ...
# 10041446    충청남도 서산시 대산읍 대산리             한미   58.4700  202408  31    3,000
# 10041447        경상북도 안동시 법흥동    안동강변펠리시아아파트  116.4457  202408  31   52,000
# 10041448        경상북도 구미시 오태동  신한디아체101동102동   59.9800  202408  31    4,700
# 10041449     경상남도 양산시 동면 석산리     양산이지더원리버포레   78.2990  202408  31   34,200
# 10041450     전북특별자치도 남원시 월락동       양우내안애아파트   59.9896  202408  31   20,900
#
#            층    건축년도       계약날짜       변경날짜  기준금리      시도교육청명   학원수
# 0         11  1998.0 2005-09-23 2004-11-11  3.25  강원특별자치도교육청    24
# 1          3  1997.0 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 2          8  1998.0 2005-10-20 2005-10-11  3.50      경기도교육청  1151
# 3         19  2003.0 2005-10-30 2005-10-11  3.50      경기도교육청  1151
# 4         11  1992.0 2005-11-21 2005-10-11  3.50      경기도교육청  1151
# ...       ..     ...        ...        ...   ...         ...   ...
# 10041446   5  1992.0 2024-08-31 2023-01-13  3.50     충청남도교육청   363
# 10041447   7  2017.0 2024-08-31 2023-01-13  3.50     경상북도교육청   390
# 10041448   1  1999.0 2024-08-31 2023-01-13  3.50     경상북도교육청  1275
# 10041449  15  2017.0 2024-08-31 2023-01-13  3.50     경상남도교육청   928
# 10041450  15  2016.0 2024-08-31 2023-01-13  3.50  전북특별자치도교육청   137
#
# [10041451 rows x 13 columns]

# %%
apt_data['학원수'].isnull().sum()
# Out:
# 1748120

# %% [markdown]
# ## 데이터베이스에서 환율정보 불러오기

# %%
from sqlalchemy import create_engine, text
import pymysql
pymysql.install_as_MySQLdb()

# %%
db = "mysql"
dbtype = "pymysql"
user = "root"
password = "1234"
host = "127.0.0.1:3306"
database = "korea_exchange_rate"

# %%
engine = create_engine(f"{db}+{dbtype}://{user}:{password}@{host}/{database}")

# %%
conn = engine.connect()

# %%
# SQL 쿼리 실행 (예: 특정 테이블의 모든 데이터 가져오기)
query = "SELECT * FROM exchange_rate" 
df = pd.read_sql(query, conn)

# %%
# 데이터프레임 확인
df.head()
# Out:
#          date            통화  현찰_살때_환율  현찰_살때_Spread  현찰_팔때_환율  현찰_팔때_Spread  \
# 0  1995-01-03        미국 USD    800.53           1.5    776.87           1.5
# 1  1995-01-03  일본 JPY (100)    798.89           1.5    775.29           1.5
# 2  1995-01-03        유로 EUR      0.00           0.0      0.00           0.0
# 3  1995-01-03        중국 CNY      0.00           0.0      0.00           0.0
# 4  1995-01-03        홍콩 HKD    103.45           3.0    100.41           3.0
#
#    송금_보낼때  송금_받을때  T/C_살때  외화_수표_팔때   매매기준율  환가_료율  미화 환산율
# 0  791.80  785.60  792.64      0.00  788.70   0.00  1.0000
# 1  791.81  782.37  792.59      0.00  787.09   0.00  0.9980
# 2  975.40  959.92    0.00    957.94  967.66   7.37  1.2269
# 3   94.12    0.00    0.00      0.00   93.38   1.00  0.1184
# 4  102.74  101.12    0.00      0.00  101.93   0.00  0.1292

# %%
df = df[df['통화'] == '미국 USD']

# %%
df = df[['date','현찰_살때_환율']]
df.head()
# Out:
#           date  현찰_살때_환율
# 0   1995-01-03    800.53
# 22  1995-01-04    800.33
# 44  1995-01-05    801.14
# 66  1995-01-06    801.44
# 88  1995-01-09    802.15

# %%
rate_data = df.copy()

# %%
rate_data.head()
# Out:
#           date  현찰_살때_환율
# 0   1995-01-03    800.53
# 22  1995-01-04    800.33
# 44  1995-01-05    801.14
# 66  1995-01-06    801.44
# 88  1995-01-09    802.15

# %%
# 연결 종료
conn.close()

# %%
rate_data.head()
# Out:
#           date  현찰_살때_환율
# 0   1995-01-03    800.53
# 22  1995-01-04    800.33
# 44  1995-01-05    801.14
# 66  1995-01-06    801.44
# 88  1995-01-09    802.15

# %%
rate_data
# Out:
#               date  현찰_살때_환율
# 0       1995-01-03    800.53
# 22      1995-01-04    800.33
# 44      1995-01-05    801.14
# 66      1995-01-06    801.44
# 88      1995-01-09    802.15
# ...            ...       ...
# 383346  2024-09-19   1351.74
# 383404  2024-09-20   1357.34
# 383462  2024-09-23   1362.53
# 383520  2024-09-24   1359.38
# 383578  2024-09-25   1354.08
#
# [9848 rows x 2 columns]

# %%
import pandas as pd

# 1. 날짜 컬럼을 datetime 형식으로 변환
rate_data['date'] = pd.to_datetime(rate_data['date'])

# 2. 전체 날짜 범위 생성 (1995-01-03 ~ 2024-09-25)
date_range = pd.date_range(start='1995-01-03', end='2024-09-25')

# 3. 기존 데이터를 이 날짜 범위에 맞춰 재구성 (누락된 날짜를 추가)
rate_data_full = pd.DataFrame(date_range, columns=['date']).merge(rate_data, on='date', how='left')

# 4. 환율 값이 0이거나 비어 있는 경우 이전 값으로 채우기
rate_data_full['현찰_살때_환율'].replace(0, pd.NA, inplace=True)  # 0인 값들을 NA로 처리
rate_data_full['현찰_살때_환율'].fillna(method='ffill', inplace=True)  # 이전 값으로 채우기

# 결과 확인
print(rate_data_full.head())
# Out:
#         date  현찰_살때_환율
# 0 1995-01-03    800.53
# 1 1995-01-04    800.33
# 2 1995-01-05    801.14
# 3 1995-01-06    801.44
# 4 1995-01-07    801.44
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\2800489824.py:13: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rate_data_full['현찰_살때_환율'].replace(0, pd.NA, inplace=True)  # 0인 값들을 NA로 처리
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\2800489824.py:14: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   rate_data_full['현찰_살때_환율'].fillna(method='ffill', inplace=True)  # 이전 값으로 채우기
# C:\Users\5-11\AppData\Local\Temp\ipykernel_11764\2800489824.py:14: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   rate_data_full['현찰_살때_환율'].fillna(method='ffill', inplace=True)  # 이전 값으로 채우기

# %%
rate_data_full
# Out:
#             date  현찰_살때_환율
# 0     1995-01-03    800.53
# 1     1995-01-04    800.33
# 2     1995-01-05    801.14
# 3     1995-01-06    801.44
# 4     1995-01-07    801.44
# ...          ...       ...
# 12958 2024-09-21   1357.34
# 12959 2024-09-22   1357.34
# 12960 2024-09-23   1362.53
# 12961 2024-09-24   1359.38
# 12962 2024-09-25   1354.08
#
# [12963 rows x 2 columns]

# %%
내가 원하는 내용은 다음과 같아
지금 academy_data에 있는 행정구역명 컬럼의 값은 apt_data의 시군구 컬럼의 값에 포함되어있는 형식이야. 예를 들어 academy_data의 행정구역명 컬럼의 값이 양구군 이고 apt_data의 시군구 컬럼의 값이 강원특별자치도 양구군 양구읍 상리 라고 되어있어. 이 상태에서 apt_data에 학원수 라는 컬럼을 추가해야 하는데
