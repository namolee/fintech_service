# %%
import sys,os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import tensorflow as tf
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Input, Conv2D, MaxPooling2D, Flatten, Dropout
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
# Out:
# 2024-09-12 17:11:38.611002: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-12 17:11:41.508792: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdirectml.d6f03b303ac3c4f2eeb8ca631688c9757b361310.so
# 2024-09-12 17:11:41.508942: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libdxcore.so
# 2024-09-12 17:11:41.512715: I tensorflow/c/logging.cc:34] Successfully opened dynamic library libd3d12.so
# 2024-09-12 17:11:41.758744: I tensorflow/c/logging.cc:34] DirectML device enumeration: found 1 compatible adapters.

# %% [markdown]
# # Image Agumention
# * 학습데이터 부족을 해결하기 위해서 이미지에 변형을 가해 새로운 이미지를 만들어 주는 것

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, array_to_img, load_img

# %%
image = load_img("./catndog/bird.jpg")
image_array = img_to_array(image)
image_array.shape
# Out:
# (703, 454, 3)

# %%
plt.imshow(image)

# %%
datagen = ImageDataGenerator(
            rescale=1. /255,
            rotation_range=40,
        width_shift_range=0.3,
        height_shift_range=0.2,
        shear_range=0.6,
        zoom_range=0.3,
        horizontal_flip=True,
        vertical_flip=True,
        fill_mode='nearest'

)

# %%
image_array.shape
# Out:
# (703, 454, 3)

# %%
image_array.reshape((1,)+image_array.shape).shape
# Out:
# (1, 703, 454, 3)

# %%
image_array = image_array.reshape((1,)+image_array.shape)

# %%
fig, axes = plt.subplots(5,4,figsize=(9,9))
axes = axes.ravel()

for i, batch in enumerate(datagen.flow(image_array, batch_size=1)):
    if i>= 20: # 20개 이미지 생성 후 종료
        break
    augmented_image = array_to_img(batch[0])
    axes[i].imshow(augmented_image)
    axes[i].axis('off')
plt.tight_layout()
plt.show()

# %% [markdown]
# # 전이학습
# * 사전에 훈련된 모델을 가지고 새로운 데이터를 넣어서 훈련하거나 결과를 출력

# %%
from tensorflow.keras.layers import GlobalMaxPooling2D, GlobalAveragePooling2D
from tensorflow.keras.applications import ResNetRS420

# %%
base_model = ResNetRS420(include_top = True,
                         weights = 'imagenet',
                        input_tensor = None,
                        input_shape = None,
                        pooling = None,
                        classes = 1000)
# Out:
# 2024-09-12 17:11:52.087659: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2024-09-12 17:11:52.089843: I tensorflow/c/logging.cc:34] DirectML: creating device on adapter 0 (AMD Radeon(TM) Graphics)
# 2024-09-12 17:11:52.170755: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:11:52.170801: W tensorflow/core/common_runtime/pluggable_device/pluggable_device_bfc_allocator.cc:28] Overriding allow_growth setting because force_memory_growth was requested by the device.
# 2024-09-12 17:11:52.170823: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/resnet_rs/resnet-rs-420-i320.h5
# 773619176/773619176 [==============================] - 24s 0us/step

# %%
base_model.summary()
# Out:
# Model: "resnet-rs-420"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 224, 224, 3  0           []
#                                 )]
#
#  rescaling (Rescaling)          (None, 224, 224, 3)  0           ['input_1[0][0]']
#
#  normalization (Normalization)  (None, 224, 224, 3)  0           ['rescaling[0][0]']
#
#  zero_padding2d (ZeroPadding2D)  (None, 226, 226, 3)  0          ['normalization[0][0]']
#
#  stem_1_stem_conv_1 (Conv2D)    (None, 112, 112, 32  864         ['zero_padding2d[0][0]']
#                                 )
#
#  stem_1_stem_batch_norm_1 (Batc  (None, 112, 112, 32  128        ['stem_1_stem_conv_1[0][0]']
#  hNormalization)                )
#
#  stem_1_stem_act_1 (Activation)  (None, 112, 112, 32  0          ['stem_1_stem_batch_norm_1[0][0]'
#                                 )                                ]
#
#  stem_1_stem_conv_2 (Conv2D)    (None, 112, 112, 32  9216        ['stem_1_stem_act_1[0][0]']
#                                 )
#
#  stem_1_stem_batch_norm_2 (Batc  (None, 112, 112, 32  128        ['stem_1_stem_conv_2[0][0]']
#  hNormalization)                )
#
#  stem_1_stem_act_2 (Activation)  (None, 112, 112, 32  0          ['stem_1_stem_batch_norm_2[0][0]'
#                                 )                                ]
#
#  stem_1_stem_conv_3 (Conv2D)    (None, 112, 112, 64  18432       ['stem_1_stem_act_2[0][0]']
#                                 )
#
#  stem_1_stem_batch_norm_3 (Batc  (None, 112, 112, 64  256        ['stem_1_stem_conv_3[0][0]']
#  hNormalization)                )
#
#  stem_1_stem_act_3 (Activation)  (None, 112, 112, 64  0          ['stem_1_stem_batch_norm_3[0][0]'
#                                 )                                ]
#
#  zero_padding2d_1 (ZeroPadding2  (None, 114, 114, 64  0          ['stem_1_stem_act_3[0][0]']
#  D)                             )
#
#  stem_1_stem_conv_4 (Conv2D)    (None, 56, 56, 64)   36864       ['zero_padding2d_1[0][0]']
#
#  stem_1_stem_batch_norm_4 (Batc  (None, 56, 56, 64)  256         ['stem_1_stem_conv_4[0][0]']
#  hNormalization)
#
#  stem_1_stem_act_4 (Activation)  (None, 56, 56, 64)  0           ['stem_1_stem_batch_norm_4[0][0]'
#                                                                  ]
#
#  BlockGroup2__block_0__conv_1 (  (None, 56, 56, 64)  4096        ['stem_1_stem_act_4[0][0]']
#  Conv2D)
#
#  BlockGroup2__block_0_batch_nor  (None, 56, 56, 64)  256         ['BlockGroup2__block_0__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup2__block_0__act_1 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_0_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup2__block_0__conv_2 (  (None, 56, 56, 64)  36864       ['BlockGroup2__block_0__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_0__batch_no  (None, 56, 56, 64)  256         ['BlockGroup2__block_0__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_0__act_2 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_0__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup2__block_0__conv_3 (  (None, 56, 56, 256)  16384      ['BlockGroup2__block_0__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_0__batch_no  (None, 56, 56, 256)  1024       ['BlockGroup2__block_0__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_0__se_se_sq  (None, 256)         0           ['BlockGroup2__block_0__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup2__block_0__se_se_re  (None, 1, 1, 256)   0           ['BlockGroup2__block_0__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup2__block_0__se_se_re  (None, 1, 1, 64)    16448       ['BlockGroup2__block_0__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#  BlockGroup2__block_0__se_se_ex  (None, 1, 1, 256)   16640       ['BlockGroup2__block_0__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup2__block_0__se_se_ex  (None, 56, 56, 256)  0          ['BlockGroup2__block_0__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup2__block_0__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup2__block_0__projecti  (None, 56, 56, 256)  16384      ['stem_1_stem_act_4[0][0]']
#  on_conv (Conv2D)
#
#  BlockGroup2__block_0__drop (Dr  (None, 56, 56, 256)  0          ['BlockGroup2__block_0__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  BlockGroup2__block_0__projecti  (None, 56, 56, 256)  1024       ['BlockGroup2__block_0__projectio
#  on_batch_norm (BatchNormalizat                                  n_conv[0][0]']
#  ion)
#
#  add (Add)                      (None, 56, 56, 256)  0           ['BlockGroup2__block_0__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup2__block_0__projectio
#                                                                  n_batch_norm[0][0]']
#
#  BlockGroup2__block_0__output_a  (None, 56, 56, 256)  0          ['add[0][0]']
#  ct (Activation)
#
#  BlockGroup2__block_1__conv_1 (  (None, 56, 56, 64)  16384       ['BlockGroup2__block_0__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup2__block_1_batch_nor  (None, 56, 56, 64)  256         ['BlockGroup2__block_1__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup2__block_1__act_1 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_1_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup2__block_1__conv_2 (  (None, 56, 56, 64)  36864       ['BlockGroup2__block_1__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_1__batch_no  (None, 56, 56, 64)  256         ['BlockGroup2__block_1__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_1__act_2 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_1__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup2__block_1__conv_3 (  (None, 56, 56, 256)  16384      ['BlockGroup2__block_1__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_1__batch_no  (None, 56, 56, 256)  1024       ['BlockGroup2__block_1__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_1__se_se_sq  (None, 256)         0           ['BlockGroup2__block_1__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup2__block_1__se_se_re  (None, 1, 1, 256)   0           ['BlockGroup2__block_1__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup2__block_1__se_se_re  (None, 1, 1, 64)    16448       ['BlockGroup2__block_1__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup2__block_1__se_se_ex  (None, 1, 1, 256)   16640       ['BlockGroup2__block_1__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup2__block_1__se_se_ex  (None, 56, 56, 256)  0          ['BlockGroup2__block_1__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup2__block_1__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup2__block_1__drop (Dr  (None, 56, 56, 256)  0          ['BlockGroup2__block_1__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_1 (Add)                    (None, 56, 56, 256)  0           ['BlockGroup2__block_1__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup2__block_0__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup2__block_1__output_a  (None, 56, 56, 256)  0          ['add_1[0][0]']
#  ct (Activation)
#
#  BlockGroup2__block_2__conv_1 (  (None, 56, 56, 64)  16384       ['BlockGroup2__block_1__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup2__block_2_batch_nor  (None, 56, 56, 64)  256         ['BlockGroup2__block_2__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup2__block_2__act_1 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_2_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup2__block_2__conv_2 (  (None, 56, 56, 64)  36864       ['BlockGroup2__block_2__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_2__batch_no  (None, 56, 56, 64)  256         ['BlockGroup2__block_2__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_2__act_2 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_2__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup2__block_2__conv_3 (  (None, 56, 56, 256)  16384      ['BlockGroup2__block_2__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_2__batch_no  (None, 56, 56, 256)  1024       ['BlockGroup2__block_2__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_2__se_se_sq  (None, 256)         0           ['BlockGroup2__block_2__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup2__block_2__se_se_re  (None, 1, 1, 256)   0           ['BlockGroup2__block_2__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup2__block_2__se_se_re  (None, 1, 1, 64)    16448       ['BlockGroup2__block_2__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup2__block_2__se_se_ex  (None, 1, 1, 256)   16640       ['BlockGroup2__block_2__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup2__block_2__se_se_ex  (None, 56, 56, 256)  0          ['BlockGroup2__block_2__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup2__block_2__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup2__block_2__drop (Dr  (None, 56, 56, 256)  0          ['BlockGroup2__block_2__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_2 (Add)                    (None, 56, 56, 256)  0           ['BlockGroup2__block_2__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup2__block_1__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup2__block_2__output_a  (None, 56, 56, 256)  0          ['add_2[0][0]']
#  ct (Activation)
#
#  BlockGroup2__block_3__conv_1 (  (None, 56, 56, 64)  16384       ['BlockGroup2__block_2__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup2__block_3_batch_nor  (None, 56, 56, 64)  256         ['BlockGroup2__block_3__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup2__block_3__act_1 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_3_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup2__block_3__conv_2 (  (None, 56, 56, 64)  36864       ['BlockGroup2__block_3__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_3__batch_no  (None, 56, 56, 64)  256         ['BlockGroup2__block_3__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_3__act_2 (A  (None, 56, 56, 64)  0           ['BlockGroup2__block_3__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup2__block_3__conv_3 (  (None, 56, 56, 256)  16384      ['BlockGroup2__block_3__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup2__block_3__batch_no  (None, 56, 56, 256)  1024       ['BlockGroup2__block_3__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup2__block_3__se_se_sq  (None, 256)         0           ['BlockGroup2__block_3__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup2__block_3__se_se_re  (None, 1, 1, 256)   0           ['BlockGroup2__block_3__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup2__block_3__se_se_re  (None, 1, 1, 64)    16448       ['BlockGroup2__block_3__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup2__block_3__se_se_ex  (None, 1, 1, 256)   16640       ['BlockGroup2__block_3__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#  BlockGroup2__block_3__se_se_ex  (None, 56, 56, 256)  0          ['BlockGroup2__block_3__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup2__block_3__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup2__block_3__drop (Dr  (None, 56, 56, 256)  0          ['BlockGroup2__block_3__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_3 (Add)                    (None, 56, 56, 256)  0           ['BlockGroup2__block_3__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup2__block_2__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup2__block_3__output_a  (None, 56, 56, 256)  0          ['add_3[0][0]']
#  ct (Activation)
#
#  BlockGroup3__block_0__conv_1 (  (None, 56, 56, 128)  32768      ['BlockGroup2__block_3__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup3__block_0_batch_nor  (None, 56, 56, 128)  512        ['BlockGroup3__block_0__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup3__block_0__act_1 (A  (None, 56, 56, 128)  0          ['BlockGroup3__block_0_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  zero_padding2d_2 (ZeroPadding2  (None, 58, 58, 128)  0          ['BlockGroup3__block_0__act_1[0][
#  D)                                                              0]']
#
#  BlockGroup3__block_0__conv_2 (  (None, 28, 28, 128)  147456     ['zero_padding2d_2[0][0]']
#  Conv2D)
#
#  BlockGroup3__block_0__batch_no  (None, 28, 28, 128)  512        ['BlockGroup3__block_0__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_0__act_2 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_0__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup3__block_0__conv_3 (  (None, 28, 28, 512)  65536      ['BlockGroup3__block_0__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_0__batch_no  (None, 28, 28, 512)  2048       ['BlockGroup3__block_0__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_0__se_se_sq  (None, 512)         0           ['BlockGroup3__block_0__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup3__block_0__se_se_re  (None, 1, 1, 512)   0           ['BlockGroup3__block_0__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup3__block_0__se_se_re  (None, 1, 1, 128)   65664       ['BlockGroup3__block_0__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup3__block_0__se_se_ex  (None, 1, 1, 512)   66048       ['BlockGroup3__block_0__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup3__block_0__projecti  (None, 28, 28, 256)  0          ['BlockGroup2__block_3__output_ac
#  on_pooling (AveragePooling2D)                                   t[0][0]']
#
#  BlockGroup3__block_0__se_se_ex  (None, 28, 28, 512)  0          ['BlockGroup3__block_0__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup3__block_0__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup3__block_0__projecti  (None, 28, 28, 512)  131072     ['BlockGroup3__block_0__projectio
#  on_conv (Conv2D)                                                n_pooling[0][0]']
#
#  BlockGroup3__block_0__drop (Dr  (None, 28, 28, 512)  0          ['BlockGroup3__block_0__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  BlockGroup3__block_0__projecti  (None, 28, 28, 512)  2048       ['BlockGroup3__block_0__projectio
#  on_batch_norm (BatchNormalizat                                  n_conv[0][0]']
#  ion)
#
#  add_4 (Add)                    (None, 28, 28, 512)  0           ['BlockGroup3__block_0__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup3__block_0__projectio
#                                                                  n_batch_norm[0][0]']
#
#  BlockGroup3__block_0__output_a  (None, 28, 28, 512)  0          ['add_4[0][0]']
#  ct (Activation)
#
#  BlockGroup3__block_1__conv_1 (  (None, 28, 28, 128)  65536      ['BlockGroup3__block_0__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup3__block_1_batch_nor  (None, 28, 28, 128)  512        ['BlockGroup3__block_1__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup3__block_1__act_1 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_1_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup3__block_1__conv_2 (  (None, 28, 28, 128)  147456     ['BlockGroup3__block_1__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_1__batch_no  (None, 28, 28, 128)  512        ['BlockGroup3__block_1__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_1__act_2 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_1__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup3__block_1__conv_3 (  (None, 28, 28, 512)  65536      ['BlockGroup3__block_1__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_1__batch_no  (None, 28, 28, 512)  2048       ['BlockGroup3__block_1__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_1__se_se_sq  (None, 512)         0           ['BlockGroup3__block_1__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup3__block_1__se_se_re  (None, 1, 1, 512)   0           ['BlockGroup3__block_1__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup3__block_1__se_se_re  (None, 1, 1, 128)   65664       ['BlockGroup3__block_1__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup3__block_1__se_se_ex  (None, 1, 1, 512)   66048       ['BlockGroup3__block_1__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup3__block_1__se_se_ex  (None, 28, 28, 512)  0          ['BlockGroup3__block_1__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup3__block_1__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup3__block_1__drop (Dr  (None, 28, 28, 512)  0          ['BlockGroup3__block_1__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_5 (Add)                    (None, 28, 28, 512)  0           ['BlockGroup3__block_1__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup3__block_0__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup3__block_1__output_a  (None, 28, 28, 512)  0          ['add_5[0][0]']
#  ct (Activation)
#
#  BlockGroup3__block_2__conv_1 (  (None, 28, 28, 128)  65536      ['BlockGroup3__block_1__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup3__block_2_batch_nor  (None, 28, 28, 128)  512        ['BlockGroup3__block_2__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup3__block_2__act_1 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_2_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup3__block_2__conv_2 (  (None, 28, 28, 128)  147456     ['BlockGroup3__block_2__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_2__batch_no  (None, 28, 28, 128)  512        ['BlockGroup3__block_2__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_2__act_2 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_2__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup3__block_2__conv_3 (  (None, 28, 28, 512)  65536      ['BlockGroup3__block_2__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_2__batch_no  (None, 28, 28, 512)  2048       ['BlockGroup3__block_2__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_2__se_se_sq  (None, 512)         0           ['BlockGroup3__block_2__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup3__block_2__se_se_re  (None, 1, 1, 512)   0           ['BlockGroup3__block_2__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup3__block_2__se_se_re  (None, 1, 1, 128)   65664       ['BlockGroup3__block_2__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#  BlockGroup3__block_2__se_se_ex  (None, 1, 1, 512)   66048       ['BlockGroup3__block_2__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup3__block_2__se_se_ex  (None, 28, 28, 512)  0          ['BlockGroup3__block_2__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup3__block_2__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup3__block_2__drop (Dr  (None, 28, 28, 512)  0          ['BlockGroup3__block_2__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_6 (Add)                    (None, 28, 28, 512)  0           ['BlockGroup3__block_2__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup3__block_1__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup3__block_2__output_a  (None, 28, 28, 512)  0          ['add_6[0][0]']
#  ct (Activation)
#
#  BlockGroup3__block_3__conv_1 (  (None, 28, 28, 128)  65536      ['BlockGroup3__block_2__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup3__block_3_batch_nor  (None, 28, 28, 128)  512        ['BlockGroup3__block_3__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup3__block_3__act_1 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_3_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup3__block_3__conv_2 (  (None, 28, 28, 128)  147456     ['BlockGroup3__block_3__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_3__batch_no  (None, 28, 28, 128)  512        ['BlockGroup3__block_3__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_3__act_2 (A  (None, 28, 28, 128)  0          ['BlockGroup3__block_3__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup3__block_3__conv_3 (  (None, 28, 28, 512)  65536      ['BlockGroup3__block_3__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup3__block_3__batch_no  (None, 28, 28, 512)  2048       ['BlockGroup3__block_3__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup3__block_3__se_se_sq  (None, 512)         0           ['BlockGroup3__block_3__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup3__block_3__se_se_re  (None, 1, 1, 512)   0           ['BlockGroup3__block_3__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup3__block_3__se_se_re  (None, 1, 1, 128)   65664       ['BlockGroup3__block_3__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup3__block_3__se_se_ex  (None, 1, 1, 512)   66048       ['BlockGroup3__block_3__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup3__block_3__se_se_ex  (None, 28, 28, 512)  0          ['BlockGroup3__block_3__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup3__block_3__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup3__block_3__drop (Dr  (None, 28, 28, 512)  0          ['BlockGroup3__block_3__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_7 (Add)                    (None, 28, 28, 512)  0           ['BlockGroup3__block_3__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup3__block_2__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup3__block_3__output_a  (None, 28, 28, 512)  0          ['add_7[0][0]']
#  ct (Activation)
#
#  BlockGroup3__block_4__conv_1 (  (None, 28, 28, 128)  65536      ['BlockGroup3__block_3__output_ac
#  Conv2D)                                                         t[0][0]']
# ...
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup5__block_1__conv_2 (  (None, 7, 7, 512)   2359296     ['BlockGroup5__block_1__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_1__batch_no  (None, 7, 7, 512)   2048        ['BlockGroup5__block_1__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_1__act_2 (A  (None, 7, 7, 512)   0           ['BlockGroup5__block_1__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup5__block_1__conv_3 (  (None, 7, 7, 2048)  1048576     ['BlockGroup5__block_1__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_1__batch_no  (None, 7, 7, 2048)  8192        ['BlockGroup5__block_1__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_1__se_se_sq  (None, 2048)        0           ['BlockGroup5__block_1__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup5__block_1__se_se_re  (None, 1, 1, 2048)  0           ['BlockGroup5__block_1__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup5__block_1__se_se_re  (None, 1, 1, 512)   1049088     ['BlockGroup5__block_1__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup5__block_1__se_se_ex  (None, 1, 1, 2048)  1050624     ['BlockGroup5__block_1__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup5__block_1__se_se_ex  (None, 7, 7, 2048)  0           ['BlockGroup5__block_1__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup5__block_1__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup5__block_1__drop (Dr  (None, 7, 7, 2048)  0           ['BlockGroup5__block_1__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_136 (Add)                  (None, 7, 7, 2048)   0           ['BlockGroup5__block_1__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup5__block_0__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup5__block_1__output_a  (None, 7, 7, 2048)  0           ['add_136[0][0]']
#  ct (Activation)
#
#  BlockGroup5__block_2__conv_1 (  (None, 7, 7, 512)   1048576     ['BlockGroup5__block_1__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup5__block_2_batch_nor  (None, 7, 7, 512)   2048        ['BlockGroup5__block_2__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup5__block_2__act_1 (A  (None, 7, 7, 512)   0           ['BlockGroup5__block_2_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup5__block_2__conv_2 (  (None, 7, 7, 512)   2359296     ['BlockGroup5__block_2__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_2__batch_no  (None, 7, 7, 512)   2048        ['BlockGroup5__block_2__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_2__act_2 (A  (None, 7, 7, 512)   0           ['BlockGroup5__block_2__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup5__block_2__conv_3 (  (None, 7, 7, 2048)  1048576     ['BlockGroup5__block_2__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_2__batch_no  (None, 7, 7, 2048)  8192        ['BlockGroup5__block_2__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_2__se_se_sq  (None, 2048)        0           ['BlockGroup5__block_2__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup5__block_2__se_se_re  (None, 1, 1, 2048)  0           ['BlockGroup5__block_2__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup5__block_2__se_se_re  (None, 1, 1, 512)   1049088     ['BlockGroup5__block_2__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup5__block_2__se_se_ex  (None, 1, 1, 2048)  1050624     ['BlockGroup5__block_2__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup5__block_2__se_se_ex  (None, 7, 7, 2048)  0           ['BlockGroup5__block_2__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup5__block_2__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup5__block_2__drop (Dr  (None, 7, 7, 2048)  0           ['BlockGroup5__block_2__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_137 (Add)                  (None, 7, 7, 2048)   0           ['BlockGroup5__block_2__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup5__block_1__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup5__block_2__output_a  (None, 7, 7, 2048)  0           ['add_137[0][0]']
#  ct (Activation)
#
#  BlockGroup5__block_3__conv_1 (  (None, 7, 7, 512)   1048576     ['BlockGroup5__block_2__output_ac
#  Conv2D)                                                         t[0][0]']
#
#  BlockGroup5__block_3_batch_nor  (None, 7, 7, 512)   2048        ['BlockGroup5__block_3__conv_1[0]
#  m_1 (BatchNormalization)                                        [0]']
#
#  BlockGroup5__block_3__act_1 (A  (None, 7, 7, 512)   0           ['BlockGroup5__block_3_batch_norm
#  ctivation)                                                      _1[0][0]']
#
#  BlockGroup5__block_3__conv_2 (  (None, 7, 7, 512)   2359296     ['BlockGroup5__block_3__act_1[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_3__batch_no  (None, 7, 7, 512)   2048        ['BlockGroup5__block_3__conv_2[0]
#  rm_2 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_3__act_2 (A  (None, 7, 7, 512)   0           ['BlockGroup5__block_3__batch_nor
#  ctivation)                                                      m_2[0][0]']
#
#  BlockGroup5__block_3__conv_3 (  (None, 7, 7, 2048)  1048576     ['BlockGroup5__block_3__act_2[0][
#  Conv2D)                                                         0]']
#
#  BlockGroup5__block_3__batch_no  (None, 7, 7, 2048)  8192        ['BlockGroup5__block_3__conv_3[0]
#  rm_3 (BatchNormalization)                                       [0]']
#
#  BlockGroup5__block_3__se_se_sq  (None, 2048)        0           ['BlockGroup5__block_3__batch_nor
#  ueeze (GlobalAveragePooling2D)                                  m_3[0][0]']
#
#  BlockGroup5__block_3__se_se_re  (None, 1, 1, 2048)  0           ['BlockGroup5__block_3__se_se_squ
#  shape (Reshape)                                                 eeze[0][0]']
#
#  BlockGroup5__block_3__se_se_re  (None, 1, 1, 512)   1049088     ['BlockGroup5__block_3__se_se_res
#  duce (Conv2D)                                                   hape[0][0]']
#
#  BlockGroup5__block_3__se_se_ex  (None, 1, 1, 2048)  1050624     ['BlockGroup5__block_3__se_se_red
#  pand (Conv2D)                                                   uce[0][0]']
#
#  BlockGroup5__block_3__se_se_ex  (None, 7, 7, 2048)  0           ['BlockGroup5__block_3__batch_nor
#  cite (Multiply)                                                 m_3[0][0]',
#                                                                   'BlockGroup5__block_3__se_se_exp
#                                                                  and[0][0]']
#
#  BlockGroup5__block_3__drop (Dr  (None, 7, 7, 2048)  0           ['BlockGroup5__block_3__se_se_exc
#  opout)                                                          ite[0][0]']
#
#  add_138 (Add)                  (None, 7, 7, 2048)   0           ['BlockGroup5__block_3__drop[0][0
#                                                                  ]',
#                                                                   'BlockGroup5__block_2__output_ac
#                                                                  t[0][0]']
#
#  BlockGroup5__block_3__output_a  (None, 7, 7, 2048)  0           ['add_138[0][0]']
#  ct (Activation)
#
#  avg_pool (GlobalAveragePooling  (None, 2048)        0           ['BlockGroup5__block_3__output_ac
#  2D)                                                             t[0][0]']
#
#  top_dropout (Dropout)          (None, 2048)         0           ['avg_pool[0][0]']
#
#  predictions (Dense)            (None, 1000)         2049000     ['top_dropout[0][0]']
#
# ==================================================================================================
# Total params: 192,262,216
# Trainable params: 191,891,656
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
base_model.trainable = False
model = Sequential()
model.add(base_model)
model.add(Dense(1, activation = 'sigmoid'))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  resnet-rs-420 (Functional)  (None, 1000)              192262216
#
#  dense (Dense)               (None, 1)                 1001
#
# =================================================================
# Total params: 192,263,217
# Trainable params: 1,001
# Non-trainable params: 192,262,216
# _________________________________________________________________

# %%
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])
modelpath = './model/ResnetRS420_catndog.keras'
checkpoint = ModelCheckpoint(filepath = modelpath, save_best_only = True)
early_stop = EarlyStopping(patience = 10)

# %%
train_dir = './catndog/train/'
valid_dir = './catndog/validation/'
batch_size = 32
image_height = 224
image_width = 224

# %%
# train에만 넣어야 함
train = ImageDataGenerator(
    rescale = 1.0/255,
    rotation_range = 40,
    width_shift_range = 0.3,
    height_shift_range = 0.2,
    shear_range = 0.6,
    zoom_range = 0.3,
    horizontal_flip = True,
    vertical_flip = True,
    fill_mode = 'nearest'
)

train_gen = train.flow_from_directory(train_dir, target_size = (image_height, image_width),
                                     color_mode = 'rgb', batch_size = batch_size,
                                     seed = 7, # random_state라고 생각하면 됨
                                     shuffle = True, class_mode = 'categorical')
# Out:
# Found 385 images belonging to 2 classes.

# %%
valid = ImageDataGenerator(rescale = 1.0 / 255)
valid_gen = valid.flow_from_directory(train_dir, target_size = (image_height, image_width),
                                     color_mode = 'rgb', batch_size = batch_size,
                                     seed = 7, # random_state라고 생각하면 됨
                                     shuffle = True, class_mode = 'categorical')
# Out:
# Found 385 images belonging to 2 classes.

# %%
history = model.fit(train_gen, epochs = 2000, validation_data = valid_gen,
                   callbacks = [early_stop, checkpoint])
# Out:
# Epoch 1/2000
# 2024-09-12 17:16:37.330560: I tensorflow/core/grappler/optimizers/custom_graph_optimizer_registry.cc:114] Plugin optimizer for device_type GPU is enabled.
# 2024-09-12 17:16:43.757365: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.757439: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.760273: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.760334: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.762196: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.762269: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.763915: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.763980: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.765862: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.765922: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.768492: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.768564: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.769699: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.769768: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.771074: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.771142: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.772313: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.772373: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.773638: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.773696: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.774774: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.774841: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.776156: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.776224: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.777430: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.777493: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.778954: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.779023: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.780166: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.780226: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.781422: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.781484: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.782501: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.782554: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.783833: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.783889: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.784936: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.784989: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.786206: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.786265: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.787393: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.787464: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.789111: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.789169: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.790225: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.790285: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.791497: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.791553: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.792622: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.792684: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.794220: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.794290: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.795405: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.795464: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.796673: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.796728: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.797808: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.797873: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.799134: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.799190: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.800217: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.800269: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.801425: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.801480: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.802515: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.802581: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.803903: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.803962: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.805089: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.805147: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.806319: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.806381: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.807452: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.807506: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.809091: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.809161: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.810378: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.810437: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.811657: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.811725: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.812849: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.812914: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.814245: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.814306: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.815347: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.815399: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.816526: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.816578: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.817627: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.817680: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.818901: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.818955: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.820033: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.820087: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.822112: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.822179: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.823310: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.823368: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.824680: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.824741: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.825905: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.825995: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.827228: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.827306: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.828407: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.828462: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.829726: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.829785: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.831176: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.831245: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.832492: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.832547: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.833615: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.833667: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.834981: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.835037: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.836044: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.836098: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.837318: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.837382: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.838571: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.838628: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.840000: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.840060: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.841155: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.841218: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.842382: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.842441: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.843487: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.843543: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.844796: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.844855: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.845861: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.845918: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.847011: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.847067: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.848090: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.848151: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.849410: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.849473: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.850536: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.850578: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.851678: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.851735: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.852735: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.852788: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.853997: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.854058: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.855175: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.855238: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.856441: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.856524: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.857599: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.857654: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.858854: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.858909: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.859981: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.860051: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.861245: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.861326: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.862367: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.862428: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.863843: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.863906: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.864952: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.865012: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.866121: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.866176: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.867201: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.867265: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.868643: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.868708: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.869784: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.869845: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.871026: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.871085: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.872193: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.872260: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.873592: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.873650: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.875234: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.875300: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.876463: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:16:43.876519: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:16:43.877557: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# ...
# 2024-09-12 17:17:49.319335: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.319388: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.320547: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.320633: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.322295: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.322377: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.323961: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.324116: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.325726: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.325782: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.326876: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.326927: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.328458: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.328516: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.329655: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.329711: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.331280: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.331342: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.332461: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.332520: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.333777: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.333830: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.334840: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.334891: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.336353: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.336410: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.337429: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.337484: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.339319: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.339395: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.340450: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.340519: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.341871: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.341928: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.343040: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.343097: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.344486: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.344550: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.346034: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.346095: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.347440: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.347515: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.348619: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.348677: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.349922: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.349976: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.350979: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.351033: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.352375: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.352439: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 2024-09-12 17:17:49.353973: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:306] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2024-09-12 17:17:49.354036: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:272] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 14845 MB memory) -> physical PluggableDevice (device: 0, name: DML, pci bus id: <undefined>)
# 13/13 [==============================] - 150s 9s/step - loss: 0.6932 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 2/2000
# 13/13 [==============================] - 102s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 3/2000
# 13/13 [==============================] - 109s 9s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 4/2000
# 13/13 [==============================] - 101s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 5/2000
# 13/13 [==============================] - 109s 9s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 6/2000
# 13/13 [==============================] - 109s 9s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 7/2000
# 13/13 [==============================] - 101s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 8/2000
# 13/13 [==============================] - 101s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 9/2000
# 13/13 [==============================] - 111s 9s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 10/2000
# 13/13 [==============================] - 101s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 11/2000
# 13/13 [==============================] - 109s 9s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 12/2000
# 13/13 [==============================] - 102s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 13/2000
# 13/13 [==============================] - 102s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 14/2000
# 13/13 [==============================] - 102s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 15/2000
# 13/13 [==============================] - 103s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 16/2000
# 13/13 [==============================] - 101s 8s/step - loss: 0.6931 - accuracy: 0.5000 - val_loss: 0.6931 - val_accuracy: 0.5000
# Epoch 17/2000
# 13/13 [==============================] - ETA: 0s - loss: 0.6931 - accuracy: 0.5000
