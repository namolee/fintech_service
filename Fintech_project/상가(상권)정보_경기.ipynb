# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("./data/소상공인시장진흥공단_상가(상권)정보_경기_202409.csv")
data.head()
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_14008\3200924126.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("./data/소상공인시장진흥공단_상가(상권)정보_경기_202409.csv")
#                  상가업소번호            상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0071854             희야  NaN        I2       음식      I203
# 1  MA0101202210A0076234     비에이치씨충호회관점  NaN        I2       음식      I210
# 2  MA0101202210A0058768        생곡메밀막국수  NaN        I2       음식      I201
# 3  MA010120220805430777           고매커피  NaN        I2       음식      I212
# 4  MA010120220805430785  꿈의부동산공인중개사사무소  NaN        L1      부동산      L102
#
#   상권업종중분류명 상권업종소분류코드    상권업종소분류명 표준산업분류코드  ...                     건물관리번호  \
# 0       일식    I20301     일식 회/초밥   I56122  ...  4122010100108160002005525
# 1    기타 간이    I21006          치킨   I56193  ...  4136025024203190001025405
# 2       한식    I20105      국수/칼국수   I56112  ...  4159011700102080000000001
# ...

# %%
data.columns
# Out:
# Index(['상가업소번호', '상호명', '지점명', '상권업종대분류코드', '상권업종대분류명', '상권업종중분류코드',
#        '상권업종중분류명', '상권업종소분류코드', '상권업종소분류명', '표준산업분류코드', '표준산업분류명', '시도코드',
#        '시도명', '시군구코드', '시군구명', '행정동코드', '행정동명', '법정동코드', '법정동명', '지번코드',
#        '대지구분코드', '대지구분명', '지번본번지', '지번부번지', '지번주소', '도로명코드', '도로명', '건물본번지',
#        '건물부번지', '건물관리번호', '건물명', '도로명주소', '구우편번호', '신우편번호', '동정보', '층정보',
#        '호정보', '경도', '위도'],
#       dtype='object')

# %%
data_gyeonggi = data[(data["상권업종대분류코드"] == "I2") & (data["시도코드"].astype(str).str.startswith("41"))]

# %% [markdown]
# ### 컬럼 선택

# %%
columns = [
    "상가업소번호", "상호명", "지점명", "상권업종대분류코드", "상권업종대분류명",
    "상권업종중분류코드", "상권업종중분류명", "상권업종소분류코드", "상권업종소분류명",
    "표준산업분류코드", "표준산업분류명", "시도코드", "시도명", "시군구코드",
    "시군구명", "행정동코드", "행정동명", "도로명코드", "도로명", "도로명주소",
    "경도", "위도"]

# %%
data_gyeonggi = data_gyeonggi[columns]

# %%
data_gyeonggi.to_csv('data_gyeonggi.csv', index=False, encoding='utf-8-sig')

# %% [markdown]
# ### ---------------------------------------------------------전처리 시작--------------------------------------------------------------------

# %%
data = pd.read_csv("./data/data_gyeonggi.csv")
data.head()
# Out:
# C:\Users\5-11\AppData\Local\Temp\ipykernel_14160\2228071279.py:1: DtypeWarning: Columns (2) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = pd.read_csv("./data/data_gyeonggi.csv")
#                  상가업소번호         상호명  지점명 상권업종대분류코드 상권업종대분류명 상권업종중분류코드  \
# 0  MA0101202210A0071854          희야  NaN        I2       음식      I203
# 1  MA0101202210A0076234  비에이치씨충호회관점  NaN        I2       음식      I210
# 2  MA0101202210A0058768     생곡메밀막국수  NaN        I2       음식      I201
# 3  MA010120220805430777        고매커피  NaN        I2       음식      I212
# 4  MA010120220805430792     푸라닭성남동점  NaN        I2       음식      I210
#
#   상권업종중분류명 상권업종소분류코드 상권업종소분류명 표준산업분류코드  ...  시도명  시군구코드     시군구명     행정동코드  \
# 0       일식    I20301  일식 회/초밥   I56122  ...  경기도  41220      평택시  41220520
# 1    기타 간이    I21006       치킨   I56193  ...  경기도  41360     남양주시  41360250
# 2       한식    I20105   국수/칼국수   I56112  ...  경기도  41590      화성시  41590540
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 167161 entries, 0 to 167160
# Data columns (total 22 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   상가업소번호     167161 non-null  object
#  1   상호명        167161 non-null  object
#  2   지점명        9032 non-null    object
#  3   상권업종대분류코드  167161 non-null  object
#  4   상권업종대분류명   167161 non-null  object
#  5   상권업종중분류코드  167161 non-null  object
#  6   상권업종중분류명   167161 non-null  object
#  7   상권업종소분류코드  167161 non-null  object
#  8   상권업종소분류명   167161 non-null  object
#  9   표준산업분류코드   167099 non-null  object
#  10  표준산업분류명    167099 non-null  object
#  11  시도코드       167161 non-null  int64
#  12  시도명        167161 non-null  object
#  13  시군구코드      167161 non-null  int64
#  14  시군구명       167161 non-null  object
#  15  행정동코드      167161 non-null  int64
#  16  행정동명       167161 non-null  object
#  17  도로명코드      167067 non-null  float64
#  18  도로명        167161 non-null  object
# ...
