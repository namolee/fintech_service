# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
from bs4 import BeautifulSoup
import datetime
import requests
from urllib3.util.retry import Retry
from requests.adapters import HTTPAdapter

# url
url = 'https://m.place.naver.com/restaurant/1085956231/review/visitor?entry=ple&reviewSort=recent'

# Webdriver headless mode setting
options = webdriver.ChromeOptions()
# options.add_argument('headless')
options.add_argument('window-size=1920x1080')
options.add_argument("disable-gpu")

# BS4 setting for secondary access
session = requests.Session()
headers = {
    "User-Agent": "user value"}

retries = Retry(total=5,
                backoff_factor=0.1,
                status_forcelist=[500, 502, 503, 504])

session.mount('http://', HTTPAdapter(max_retries=retries))

# Start crawling/scraping!
try:
    driver = webdriver.Chrome(service=Service(ChromeDriverManager().install()), options=options)
    res = driver.get(url)
    driver.implicitly_wait(30)

    # Pagedown
    driver.find_element(By.TAG_NAME, 'body').send_keys(Keys.PAGE_DOWN)

    try:
        for i in range(30):  # 최대 30번 반복
            driver.find_element(By.XPATH, '//*[@id="app-root"]/div/div/div/div[6]/div[2]/div[3]/div[2]/div/a').click()
            time.sleep(0.4)
    except Exception as e:
        print('finish')
    else:
        print('30times_finish')

    time.sleep(25)
    html = driver.page_source
    bs = BeautifulSoup(html, 'lxml')
    reviews = bs.select('li.pui__X35jYm.EjjAW')

    for r in reviews:
        # nickname
        nickname = r.select_one('div.pui__JiVbY3 > span.pui__uslU0d')

        # content
        content = r.select_one('div.pui__vn15t2 > a.pui__xtsQN-')

        # date
        date_elements = r.select('div.pui__QKE5Pr > span.pui__gfuUIT > time')
        date = date_elements[0] if date_elements else 'N/A'

        # revisit
        revisit_span = r.select('div.pui__QKE5Pr > span.pui__gfuUIT')
        revisit = revisit_span[1] if len(revisit_span) > 1 else 'N/A'

        # exception handling
        nickname = nickname.text if nickname else ''
        content = content.text if content else ''
        date = date.text if date else ''
        revisit = revisit.text if revisit else ''
        time.sleep(0.06)

        # print results
        print(nickname, '/', content, '/', date, '/', revisit)
        time.sleep(0.06)

except Exception as e:
    print(e)
# Out:
# finish
# 경상도행님 / 음식들이 맛있고 분위기도 엄청 좋아요. / 11.2.토 / 2번째 방문
# mir**** / 하이볼 맛있고 감튀도 맛있어요!! 분위기도 짱 좋슴미다! / 11.2.토 / 1번째 방문
# su**** / 음식도 너무 맛있고 분위기도 너무 좋아요💕💕 하이볼 종류도 다양하고 진짜 맛있습니다!.! 대화하기도 좋네여 ㅎㅎ 추천합니다! / 10.31.목 / 1번째 방문
# ch**** / 어둑어둑하고 노래도 좋고 분위기도 좋고 음식도 맛있어서 술이 술술 들어갑니다! / 10.30.수 / 1번째 방문
# hyonly3 / 분위기좋고 대화하기 좋습니다. / 10.24.목 / 2번째 방문
# 알토란72 / 분위기좋아요 / 10.24.목 / 1번째 방문
# aimean / 육회 너무너무 맛있고, 하이볼도 달달한 하이볼부터 조니워커 하이볼까지 종류가 다양해서 골라 마시는재미가 있어요 🥰 가게 조명이나 분위기가 너무 좋아 대화하기도 좋습니다! 좋은 시간 보내고 가요 감사합니다 🧡 / 10.18.금 / 1번째 방문
# 오차원아이 / 💕분위기가 이뻐서 친구나 지인과 와서 사진찍기 좋고무엇보다 가까운 위치에 하이볼 무제한 맛집이 있어서너무 좋아요 이런 좋은 곳을 이제야 알게 된게 아쉬울정도이네요 직원분들도 친절하시고 노래도 좋아서대화하기 편해요!! ㅎㅎㅎㅎ / 10.18.금 / 1번째 방문
# hye**** / 친구랑 가볍게 한잔 하러 가기 너무 좋고2차로 가볍게 먹기 좋은 안주들과 1차로 파스타 같은 요리도 먹을 수 있어서 좋았어요전체적인 분위기는 조용조용한 재즈바 느낌?같이 간 일행하고 대화에 조금 더 집중 할 수 있구요 음식하고 술도 빠르게 나와서 더 좋습니다!왕십리, 행당시장에서 찾아가기 너무 좋은 위치 ㅎㅎ소개팅이나 생일 모임 같은 것도 많이들 하시더라구요~ / 9.6.금 / 1번째 방문
# lgy**** / 분위기 좋고 주문한 메뉴도 다 맛있었습니다👍👍 / 9.6.금 / 1번째 방문
# 액터스 / 안주가 굉장히 맛있는 술집입니다분위기도 좋아서 데이트하기 매우 좋습니다소개팅 2차로도 괜찮을듯 해요 / 9.2.월 / 1번째 방문
# 모닉킴 / 칭구랑 하이볼을 너무 좋아해서 찾아서 왔는데 역시나 너무 만족입니다. 하이볼 무제한 메뉴로 종류별로 마셔봤는데 정말 모두 너무 맛있습니다. 너무 달지도 알콜이 너무 세지도 연하지도 않아요. 오늘은 식사를 하고 배부른 상태에서 와서 안주를 못 먹었지만 다음엔 와서 안주랑 같이 먹어봐야겠어요~왕십리에서 분위기 있게 하이볼을 마시고 싶다면?? 과감히 추천입니다~~~!!! / 8.30.금 / 1번째 방문
# asdqlkwje73 / 모임하기 적당한 장소입니다하이볼 종류도 많거 음식도 맛있어요 / 8.29.목 / 1번째 방문
# psm**** / 데이트하러 우연히 들어와서 봤는데분위기도 좋고 하이볼 종류도 많아서 좋은 시간 보내고 가오~!위스키별로 하이볼 마실수있어서 좋아요! / 8.29.목 / 1번째 방문
# 정민160 / 생일 기념해서 여자친구랑 다녀왔는데 분위기도 너무 좋고 안주도 정말 맛있습니다! 무엇보다도 양귀비 하이볼이 진짜... 너무 맛있어서 계속 생각날 것 같습니다. 재방문 의향 100%.. 기념일 데이트 코스로 강추합니다 / 8.29.목 / 1번째 방문
# 안나46 / 하이볼이 다양해서 골라먹는 재미가 있어요안주가 기본적으로 맛있고 노래 플레이리스트가 좋아요 / 8.24.토 / 1번째 방문
# kiaile97 / 매뉴도 전부 맛있고 사장님도 친절하시고 분위기도 너무 좋아요ㅠㅠㅠ 특히 뇨끼 강추합니다🩷 / 8.24.토 / 1번째 방문
# 조윤원 / 분위기가 너무 좋고 하이볼이 맛있어요. 데이트할때 오기 좋을거같아요. 뇨끼도 맛있습니다 / 8.21.수 / 1번째 방문
# 221B87 / 왕십리 근처 올 일 있어서 동기들이랑 놀러왔는데 안주도 너무 맛있고 하이볼도 존맛탱입니다!! 담에 또 올게요~~ / 8.19.월 / 1번째 방문
# 김여울 / 분위기 좋고 조용한 왕십리 술집 드디어 찾았어요 🥹 친구들이 놀러와서 제가 데려간 곳인데 다들 너무 맘에들어해서 뿌듯했습니다 💕 / 8.17.토 / 1번째 방문
# 디디정 / 왕십리예술집 수컷웅 하이볼종류도 많고 음식도 다양하고 가성비터져서 좋아요ㅎ 재방문의사 200프로ㅎ 다음에는 뇨끼먹으러갑니닷ㅎ / 8.13.화 / 1번째 방문
# 로맨틱사운드 / 왕십리역 데이트 여기로 무조건 오세요💕분위기 너무 좋고 사진도 너무 잘 나오고 하이볼도 종류가 많아서 취향껏 먹을 수 있어요~데이트 뿐만 아니라 소개팅 장소로도 너무 좋을 것 같은게 딱! 여자들이 좋아할 은은한 조명에 잔잔한 노래까지 흐르는 곳이라 완전 추천해요😍하이볼 무제한으로 시켜서 종류별로 맛있게 즐기고 갑니다! / 8.7.수 / 1번째 방문
# sol**** / 분위기도 넘 좋고 음식도 맛있는 술집입니다! 하이볼이랑 위스키 종류 다양하게 있어서 좋구요 홍게장 파스타, 볶음밥 다 맛있었지만 제 원픽은 오븐 삼겹 플레이트👍 고기가 보들보들해서 좋아요 왕십리 근처 술집 중 시끄럽지 않고 대화하기 좋은 곳으로 추천합니다! / 8.3.토 / 1번째 방문
# 춤추는팅커벨 / 2차로 와서 배부른 상태지만 뇨끼맛집이라 한번 시켜봤더니 끝쨩~~~ 이야 ㅎㅎㅎ 감자튀김에 트러플오일 향이 끝납니다!!!! 여기에요 여기 오세뇽 ㅎㅎㅎㅎ / 8.3.토 / 1번째 방문
# 비서제이 / 분위기 좋고 하이볼 종류가 다양해서 데이트나 모임하기 좋아요:) / 8.2.금 / 1번째 방문
# 플로렌스Florence / 술이 다양하고 안주도 맛있어요!분위기가 좋아 데이트하러오기 좋네요 ㅎㅎ / 8.1.목 / 1번째 방문
# 쩝쩝박사박사 / 분위기도 좋고 하이볼 무제한이 아주 좋아요 하이볼도 마싯어여 최고최고 / 8.1.목 / 1번째 방문
# gus**** / 오늘 너무 맛있게 먹구갑니다….!!!!!!! / 7.30.화 / 1번째 방문
# Flower Young15 / 음악과 분위기 그리고 하이볼이 다한 곳 / 7.26.금 / 1번째 방문
# 탐방러3 / 분위기 넘  좋았어요데이트하기에 좋은 술집 / 7.26.금 / 1번째 방문
# sunnykk / 사장님이 정말 친절하시고 음식이 너무 맛있어요!! 분위기도 좋고 음악도 좋아하는 음악이 많이 나와서 너무 즐거운 시간 보내다가 가요 ㅎㅎ 다음에 또 방문할 예정!! / 7.20.토 / 1번째 방문
# 맛토리탱 / 2차로 자주 오는 곳인데 오늘은 배도 좀 고파서 super hungry 메뉴로 주문했네요^^ 생일기념이기도하고 분위기내러오기너무 좋아요. 폴라로이드 사진 이벤트도 너무 좋아요😊 자주 들를께요~ 번창하세요 :) / 7.20.토 / 2번째 방문
# 인프제 효띠 / 분위기가 정말 좋았어요!!그리고 하이볼 맛집답게 하이볼 종류가 많아서 고르는 재미가 있었어요. 하이볼도 맛있었고🤤오븐삼겹플레이트가 넘 맛있었어요 👍 / 7.20.토 / 1번째 방문
