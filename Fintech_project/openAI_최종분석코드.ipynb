# %% [markdown]
# # 구글

# %%
import os
import openai
import pandas as pd
import time

# OpenAI API 키 설정
openai.api_key 
# 입력 및 출력 폴더 경로
input_folder = "C:/fintech_service/Fintech_project/kakaobefore"
output_folder = "C:/fintech_service/Fintech_project/kakaoafter"

# 입력 폴더의 모든 CSV 파일 가져오기
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

# 각 파일에 대해 감성 분석 수행
for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_분석.csv")
    
    try:
        # CSV 파일 불러오기
        reviews_df = pd.read_csv(input_path)
        
        # 감성 분석 결과를 저장할 리스트
        sentiments = []

        # 리뷰마다 감성 분석 수행
        for review_text in reviews_df['Review']:  # 컬럼명이 'Review'라고 가정
            try:
                # 최신 ChatCompletion 모델을 사용한 감성 분석
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo-1106",
                    messages=[
                        {"role": "system", "content": "당신은 감성 분석을 전문으로 하는 도움말 어시스턴트입니다. 문맥이 없는 단어(예: '좋아요', '별로예요')만 있는 경우, 단어의 감성에 따라 '긍정적' 또는 '부정적'으로 응답하세요."},
                        {"role": "user", "content": f"다음 리뷰의 감성을 분석하여 '긍정적' 또는 '부정적' 형식으로만 응답해 주세요: '{review_text}'"}
                    ],
                    max_tokens=20,
                    temperature=0.2
                )
                
                # API 응답에서 감성 분석 결과 추출
                response_text = response.choices[0].message['content'].strip()
                if "긍정적" in response_text:
                    sentiment = "긍정적"
                elif "부정적" in response_text:
                    sentiment = "부정적"
                else:
                    sentiment = "알 수 없음"
                
                sentiments.append(sentiment)
            except Exception as e:
                print(f"리뷰 처리 중 오류 발생: {e}")
                sentiments.append("오류")
                time.sleep(1)
            
            # 요청 빈도 제어
            time.sleep(0.5)
        
        # 결과를 데이터프레임에 추가
        reviews_df['sentiment'] = sentiments

        # 결과를 파일로 저장
        reviews_df.to_csv(output_path, index=False)
        print(f"감성 분석 완료 및 결과 저장: {output_path}")

    except Exception as e:
        print(f"파일 처리 중 오류 발생: {e}")

print("모든 파일 처리 완료")
# Out:
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\9CAFE_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\고가네철판불백_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\고래똥_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\고불초쌈밥_2호점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\고품격커피공장_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\곰바로곰탕_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\곰작골나주곰탕_역삼초교점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\교토일식_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\궁민김밥_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\깡돈_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\낙여삼_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\난타5000_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\남강매점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\노브랜드버거_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\다돈식당_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\다슬음_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\더벤티_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\더에이치_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\돼지벅스_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\두두돼지불백_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\두메_도곡점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\드시옹_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\또봉이통닭_도곡점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\뚜레쥬르_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\라망드쉐프_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\리첸_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\만복회해산물_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\맥도날드_서초뱅뱅점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\맥켄치킨_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\메종보탄_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\멜론_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\명동할머니국수_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\무화잠_강남점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\문화시민_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\뱅뱅막국수_역삼본점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\버드나무집_서초본점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\봉구스밥버거_역삼삼일점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\봉평착한메밀_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\봉피양_양재점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\북경반점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\브라운돈까스_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\비채_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\사람사는고깃집김일도_뱅뱅점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\사천루_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\샵5827_에스프레소_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\서초골_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\서초남순남순대국_본점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\세로방_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\소뭉집_본점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\스노우폭스_뱅뱅점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\스타벅스_서초태우빌딩점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\시원한대구탕_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\썸_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\아워948_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\아티제_강남유니온센터점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\아티제_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\어가람_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\엄마손맛집밥세로방_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\에슬로우커피_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\에이림커피_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\영이네추억의떡볶이_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\예당_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\오늘은_어떤닭_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\오로스트커피_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\오아시스_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\왕산골_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\우심터_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\원할매이모네닭한마리_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\월참치_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\웰니스_쌀빵_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\유니마카롱_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\이천쌀밥_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\잇풀키토김밥_샌드위치_샐러드_강남점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\장수촌풍천장어_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\전주피순대_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\조순금닭도리탕_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\중화카츠_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\지우네_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\짜짜루_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\참족_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\청담배짱이_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\카린지린가네스낵바_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\카페S_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\카페블랑131_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\칸꼬시_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\커피박스_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\커피콩스토리_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\쿡쿡쿡_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\큐뮬러스_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\통돼지_두루치기김치찌개_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\파라노이드_강남뱅뱅_카페_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\파리바게뜨_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\파스쿠찌_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\파스타엔포크_강남역삼점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\판문점부대찌개_역삼점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\한강수_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\해머스미스커피_뱅뱅사거리점_reviews_kakao_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/kakaoafter\회춘식당_reviews_kakao_분석.csv
# 모든 파일 처리 완료

# %% [markdown]
# # 네이버

# %%
import os
import openai
import pandas as pd
import time

# OpenAI API 키 설정
openai.api_key 
# 입력 및 출력 폴더 경로
input_folder = "C:/fintech_service/Fintech_project/네이버분석전"
output_folder = "C:/fintech_service/Fintech_project/네이버분석후"

# 입력 폴더의 모든 CSV 파일 가져오기
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

# 각 파일에 대해 감성 분석 수행
for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_분석.csv")
    
    try:
        # CSV 파일 불러오기
        reviews_df = pd.read_csv(input_path)
        
        # 감성 분석 결과를 저장할 리스트
        sentiments = []

        # 리뷰마다 감성 분석 수행
        for review_text in reviews_df['Review']:  # 컬럼명이 'Review'라고 가정
            try:
                # 최신 ChatCompletion 모델을 사용한 감성 분석
                response = openai.ChatCompletion.create(
                    model="gpt-3.5-turbo-1106",
                    messages=[
                        {"role": "system", "content": "당신은 감성 분석을 전문으로 하는 도움말 어시스턴트입니다. 문맥이 없는 단어(예: '좋아요', '별로예요')만 있는 경우, 단어의 감성에 따라 '긍정적' 또는 '부정적'으로 응답하세요."},
                        {"role": "user", "content": f"다음 리뷰의 감성을 분석하여 '긍정적' 또는 '부정적' 형식으로만 응답해 주세요: '{review_text}'"}
                    ],
                    max_tokens=20,
                    temperature=0.2
                )
                
                # API 응답에서 감성 분석 결과 추출
                response_text = response.choices[0].message['content'].strip()
                if "긍정적" in response_text:
                    sentiment = "긍정적"
                elif "부정적" in response_text:
                    sentiment = "부정적"
                else:
                    sentiment = "알 수 없음"
                
                sentiments.append(sentiment)
            except Exception as e:
                print(f"리뷰 처리 중 오류 발생: {e}")
                sentiments.append("오류")
                time.sleep(1)
            
            # 요청 빈도 제어
            time.sleep(0.5)
        
        # 결과를 데이터프레임에 추가
        reviews_df['sentiment'] = sentiments

        # 결과를 파일로 저장
        reviews_df.to_csv(output_path, index=False)
        print(f"감성 분석 완료 및 결과 저장: {output_path}")

    except Exception as e:
        print(f"파일 처리 중 오류 발생: {e}")

print("모든 파일 처리 완료")
# Out:
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\OUR948_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\S카페_reviews_분석.csv
# 리뷰 처리 중 오류 발생: The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_d0f9a01319fec5d3be7e561f66f3650b in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_d0f9a01319fec5d3be7e561f66f3650b in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_d0f9a01319fec5d3be7e561f66f3650b in your email.)', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Fri, 22 Nov 2024 00:25:36 GMT', 'Content-Type': 'application/json', 'Content-Length': '369', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-processing-ms': '55', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '7774', 'x-ratelimit-remaining-tokens': '199880', 'x-ratelimit-reset-requests': '5h20m27.794s', 'x-ratelimit-reset-tokens': '36ms', 'x-request-id': 'req_d0f9a01319fec5d3be7e561f66f3650b', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '8e64c87f5927d1e5-ICN', 'alt-svc': 'h3=":443"; ma=86400'}
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\가정식집밥 세로방_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\고가네철판불백_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\고래똥_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\고품격커피공장 뱅뱅사거리점_reviews_분석.csv
# 리뷰 처리 중 오류 발생: The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_4a3e85abe8d4e6e0cae2bbe94ae768bb in your email.) {
#   "error": {
#     "message": "The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_4a3e85abe8d4e6e0cae2bbe94ae768bb in your email.)",
#     "type": "server_error",
#     "param": null,
#     "code": null
#   }
# } 500 {'error': {'message': 'The server had an error processing your request. Sorry about that! You can retry your request, or contact us through our help center at help.openai.com if you keep seeing this error. (Please include the request ID req_4a3e85abe8d4e6e0cae2bbe94ae768bb in your email.)', 'type': 'server_error', 'param': None, 'code': None}} {'Date': 'Fri, 22 Nov 2024 00:45:39 GMT', 'Content-Type': 'application/json', 'Content-Length': '369', 'Connection': 'keep-alive', 'access-control-expose-headers': 'X-Request-ID', 'openai-processing-ms': '53', 'x-ratelimit-limit-requests': '10000', 'x-ratelimit-limit-tokens': '200000', 'x-ratelimit-remaining-requests': '6885', 'x-ratelimit-remaining-tokens': '199872', 'x-ratelimit-reset-requests': '7h28m26.905s', 'x-ratelimit-reset-tokens': '38ms', 'x-request-id': 'req_4a3e85abe8d4e6e0cae2bbe94ae768bb', 'strict-transport-security': 'max-age=31536000; includeSubDomains; preload', 'CF-Cache-Status': 'DYNAMIC', 'X-Content-Type-Options': 'nosniff', 'Server': 'cloudflare', 'CF-RAY': '8e64e5dcecf7aa3b-ICN', 'alt-svc': 'h3=":443"; ma=86400'}
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[1], line 32
#      29 for review_text in reviews_df['Review']:  # 컬럼명이 'Review'라고 가정
#      30     try:
#      31         # 최신 ChatCompletion 모델을 사용한 감성 분석
# ---> 32         response = openai.ChatCompletion.create(
#      33             model="gpt-3.5-turbo-1106",
#      34             messages=[
#      35                 {"role": "system", "content": "당신은 감성 분석을 전문으로 하는 도움말 어시스턴트입니다. 문맥이 없는 단어(예: '좋아요', '별로예요')만 있는 경우, 단어의 감성에 따라 '긍정적' 또는 '부정적'으로 응답하세요."},
#      36                 {"role": "user", "content": f"다음 리뷰의 감성을 분석하여 '긍정적' 또는 '부정적' 형식으로만 응답해 주세요: '{review_text}'"}
#      37             ],
#      38             max_tokens=20,
#      39             temperature=0.2
#      40         )
#      42         # API 응답에서 감성 분석 결과 추출
#      43         response_text = response.choices[0].message['content'].strip()
#
# File ~\miniforge3\envs\openai\Lib\site-packages\openai\api_resources\chat_completion.py:25, in ChatCompletion.create(cls, *args, **kwargs)
#      23 while True:
#      24     try:
# ---> 25         return super().create(*args, **kwargs)
#      26     except TryAgain as e:
#      27         if timeout is not None and time.time() > start + timeout:
#
# File ~\miniforge3\envs\openai\Lib\site-packages\openai\api_resources\abstract\engine_api_resource.py:153, in EngineAPIResource.create(cls, api_key, api_base, api_type, request_id, api_version, organization, **params)
#     127 @classmethod
#     128 def create(
#     129     cls,
#    (...)
#     136     **params,
#     137 ):
#     138     (
#     139         deployment_id,
#     140         engine,
#    (...)
#     150         api_key, api_base, api_type, api_version, organization, **params
#     151     )
# --> 153     response, _, api_key = requestor.request(
#     154         "post",
#     155         url,
#     156         params=params,
#     157         headers=headers,
#     158         stream=stream,
#     159         request_id=request_id,
#     160         request_timeout=request_timeout,
#     161     )
#     163     if stream:
#     164         # must be an iterator
#     165         assert not isinstance(response, OpenAIResponse)
#
# File ~\miniforge3\envs\openai\Lib\site-packages\openai\api_requestor.py:288, in APIRequestor.request(self, method, url, params, headers, files, stream, request_id, request_timeout)
#     277 def request(
#     278     self,
#     279     method,
#    (...)
#     286     request_timeout: Optional[Union[float, Tuple[float, float]]] = None,
#     287 ) -> Tuple[Union[OpenAIResponse, Iterator[OpenAIResponse]], bool, str]:
# --> 288     result = self.request_raw(
#     289         method.lower(),
#     290         url,
#     291         params=params,
#     292         supplied_headers=headers,
#     293         files=files,
#     294         stream=stream,
#     295         request_id=request_id,
#     296         request_timeout=request_timeout,
#     297     )
#     298     resp, got_stream = self._interpret_response(result, stream)
#     299     return resp, got_stream, self.api_key
#
# File ~\miniforge3\envs\openai\Lib\site-packages\openai\api_requestor.py:596, in APIRequestor.request_raw(self, method, url, params, supplied_headers, files, stream, request_id, request_timeout)
#     594     _thread_context.session_create_time = time.time()
#     595 try:
# --> 596     result = _thread_context.session.request(
#     597         method,
#     598         abs_url,
#     599         headers=headers,
#     600         data=data,
#     601         files=files,
#     602         stream=stream,
#     603         timeout=request_timeout if request_timeout else TIMEOUT_SECS,
#     604         proxies=_thread_context.session.proxies,
#     605     )
#     606 except requests.exceptions.Timeout as e:
#     607     raise error.Timeout("Request timed out: {}".format(e)) from e
#
# File ~\miniforge3\envs\openai\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniforge3\envs\openai\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniforge3\envs\openai\Lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniforge3\envs\openai\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\miniforge3\envs\openai\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniforge3\envs\openai\Lib\site-packages\urllib3\connection.py:507, in HTTPConnection.getresponse(self)
#     504 from .response import HTTPResponse
#     506 # Get the response from http.client.HTTPConnection
# --> 507 httplib_response = super().getresponse()
#     509 try:
#     510     assert_header_parsing(httplib_response.msg)
#
# File ~\miniforge3\envs\openai\Lib\http\client.py:1395, in HTTPConnection.getresponse(self)
#    1393 try:
#    1394     try:
# -> 1395         response.begin()
#    1396     except ConnectionError:
#    1397         self.close()
#
# File ~\miniforge3\envs\openai\Lib\http\client.py:325, in HTTPResponse.begin(self)
#     323 # read until we get a non-100 response
#     324 while True:
# --> 325     version, status, reason = self._read_status()
#     326     if status != CONTINUE:
#     327         break
#
# File ~\miniforge3\envs\openai\Lib\http\client.py:286, in HTTPResponse._read_status(self)
#     285 def _read_status(self):
# --> 286     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     287     if len(line) > _MAXLINE:
#     288         raise LineTooLong("status line")
#
# File ~\miniforge3\envs\openai\Lib\socket.py:718, in SocketIO.readinto(self, b)
#     716 while True:
#     717     try:
# --> 718         return self._sock.recv_into(b)
#     719     except timeout:
#     720         self._timeout_occurred = True
#
# File ~\miniforge3\envs\openai\Lib\ssl.py:1314, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1310     if flags != 0:
#    1311         raise ValueError(
#    1312           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1313           self.__class__)
# -> 1314     return self.read(nbytes, buffer)
#    1315 else:
#    1316     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniforge3\envs\openai\Lib\ssl.py:1166, in SSLSocket.read(self, len, buffer)
#    1164 try:
#    1165     if buffer is not None:
# -> 1166         return self._sslobj.read(len, buffer)
#    1167     else:
#    1168         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
import os
import openai
import pandas as pd
import time

# OpenAI API 키 설정
openai.api_key 
# 입력 및 출력 폴더 경로
input_folder = "C:/fintech_service/Fintech_project/네이버분석전"
output_folder = "C:/fintech_service/Fintech_project/네이버분석후"

# 출력 폴더가 존재하지 않으면 생성
os.makedirs(output_folder, exist_ok=True)

# 입력 폴더의 모든 CSV 파일 가져오기
csv_files = [file for file in os.listdir(input_folder) if file.endswith('.csv')]

# 각 파일에 대해 감성 분석 수행
for csv_file in csv_files:
    input_path = os.path.join(input_folder, csv_file)
    output_path = os.path.join(output_folder, f"{os.path.splitext(csv_file)[0]}_분석.csv")
    
    try:
        # CSV 파일 불러오기
        reviews_df = pd.read_csv(input_path)
        
        # 감성 분석 결과를 저장할 리스트
        sentiments = []

        # 리뷰마다 감성 분석 수행
        for review_text in reviews_df['Review']:  # 컬럼명이 'Review'라고 가정
            retries = 3  # 최대 재시도 횟수
            sentiment = "오류"  # 기본 값

            for attempt in range(retries):
                try:
                    # 최신 ChatCompletion 모델을 사용한 감성 분석
                    response = openai.ChatCompletion.create(
                        model="gpt-3.5-turbo-1106",
                        messages=[
                            {"role": "system", "content": "당신은 감성 분석을 전문으로 하는 도움말 어시스턴트입니다. 문맥이 없는 단어(예: '좋아요', '별로예요')만 있는 경우, 단어의 감성에 따라 '긍정적' 또는 '부정적'으로 응답하세요."},
                            {"role": "user", "content": f"다음 리뷰의 감성을 분석하여 '긍정적' 또는 '부정적' 형식으로만 응답해 주세요: '{review_text}'"}
                        ],
                        max_tokens=20,
                        temperature=0.2
                    )
                    
                    # API 응답에서 감성 분석 결과 추출
                    response_text = response.choices[0].message['content'].strip()
                    if "긍정적" in response_text:
                        sentiment = "긍정적"
                    elif "부정적" in response_text:
                        sentiment = "부정적"
                    else:
                        sentiment = "알 수 없음"
                    
                    break  # 정상 처리되면 반복 종료
                except Exception as e:
                    print(f"리뷰 처리 중 오류 발생 (시도 {attempt + 1}/{retries}): {e}")
                    time.sleep(2)  # 재시도 전 대기

            sentiments.append(sentiment)
            time.sleep(1)  # 요청 간 대기 시간
        
        # 결과를 데이터프레임에 추가
        reviews_df['sentiment'] = sentiments

        # 결과를 파일로 저장
        reviews_df.to_csv(output_path, index=False)
        print(f"감성 분석 완료 및 결과 저장: {output_path}")

    except Exception as e:
        print(f"파일 처리 중 오류 발생: {e}")

print("모든 파일 처리 완료")
# Out:
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\사람사는고깃집김일도 뱅뱅점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\사천루_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\소뭉집 본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\스노우폭스 뱅뱅점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\스타벅스 서초태우빌딩점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\시원한대구탕_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\아티제 강남유니온센터점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\아티제 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\양재족발 참족_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\에슬로우 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\에이림커피_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\영이네_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\예당_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\오늘은 어떤 닭_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\오로스트커피_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\오하나 도곡점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\왕산골_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\원할매이모네닭한마리_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\월참치_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\이천쌀밥_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\잇풀_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\장수촌풍천장어_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\전주피순대_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\조순금닭도리탕_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\중화카츠&덮밥 역삼본점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\지우네_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\짜짜루_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\청담배짱이_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\카린지린가네스낵바 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\카페블랑131_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\칸꼬시_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\커피박스_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\큐뮬러스_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\통돼지두루치기김치찌개전문점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\파라노이드 강남뱅뱅 카페_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\파리바게뜨 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\파스쿠찌 뱅뱅사거리점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\판문점부대찌개 역삼점_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\한강수_reviews_분석.csv
# 감성 분석 완료 및 결과 저장: C:/fintech_service/Fintech_project/네이버분석후\회춘식당_reviews_분석.csv
# 모든 파일 처리 완료
