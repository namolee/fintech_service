# %% [markdown]
# # 파이썬에서 그래프를 그릴 때 사용하는 Matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (3.9.1)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (1.4.5)
# Requirement already satisfied: numpy>=1.23 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (2.0.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (24.1)
# Requirement already satisfied: pillow>=8 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (10.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from matplotlib) (2.9.0)
# Requirement already satisfied: six>=1.5 in c:\users\5-11\miniforge3\envs\fintech\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## 간단한 그래프 예제

# %%
fig, ax = plt.subplots()
ax.plot([1,2,3,4],[1,4,2,3]) # x,y
plt.show()

# %%
figure: 전체 그래프가 그려지는 도화지
axes: 한 칸에 그려지는 그래프
axis: 그래프의 x,y 축 눈금

# %% [markdown]
# * 그래프 없이 빈 도화지 만들기

# %%
fig=plt.figure()
plt.show()

# %% [markdown]
# * x,y 축이 하나씩 있는 그래프 그리기

# %%
fig, ax = plt.subplots()
plt.show()

# %% [markdown]
# 2 X 2로 4개 그래프 그리기

# %%
fig.ax=plt.subplots(2,2)
plt.show()

# %%
2 X 2 그래프에서 왼쪽 행 결합하기

# %%
fig, axs = plt.subplot_mosaic([['left', 'right_top'],
                               ['left', 'right_bottom']])
plt.show()

# %%
fig, axs = plt.subplot_mosaic([['top', 'top'],
                               ['bottom', 'right']])
plt.show()

# %% [markdown]
# # Matplotlib의 2가지 코딩 스타일

# %% [markdown]
# ## oo-스타일 -Matplotlib 공식 추천 스타일
# * 복잡한 그래프를 그릴 때 사용
# * 사용법이 pyplot 스타일보다 복잡함

# %%
x = np.linspace(0,2,100)
x
# Out:
# array([0.        , 0.02020202, 0.04040404, 0.06060606, 0.08080808,
#        0.1010101 , 0.12121212, 0.14141414, 0.16161616, 0.18181818,
#        0.2020202 , 0.22222222, 0.24242424, 0.26262626, 0.28282828,
#        0.3030303 , 0.32323232, 0.34343434, 0.36363636, 0.38383838,
#        0.4040404 , 0.42424242, 0.44444444, 0.46464646, 0.48484848,
#        0.50505051, 0.52525253, 0.54545455, 0.56565657, 0.58585859,
#        0.60606061, 0.62626263, 0.64646465, 0.66666667, 0.68686869,
#        0.70707071, 0.72727273, 0.74747475, 0.76767677, 0.78787879,
#        0.80808081, 0.82828283, 0.84848485, 0.86868687, 0.88888889,
#        0.90909091, 0.92929293, 0.94949495, 0.96969697, 0.98989899,
#        1.01010101, 1.03030303, 1.05050505, 1.07070707, 1.09090909,
#        1.11111111, 1.13131313, 1.15151515, 1.17171717, 1.19191919,
#        1.21212121, 1.23232323, 1.25252525, 1.27272727, 1.29292929,
#        1.31313131, 1.33333333, 1.35353535, 1.37373737, 1.39393939,
#        1.41414141, 1.43434343, 1.45454545, 1.47474747, 1.49494949,
#        1.51515152, 1.53535354, 1.55555556, 1.57575758, 1.5959596 ,
#        1.61616162, 1.63636364, 1.65656566, 1.67676768, 1.6969697 ,
#        1.71717172, 1.73737374, 1.75757576, 1.77777778, 1.7979798 ,
#        1.81818182, 1.83838384, 1.85858586, 1.87878788, 1.8989899 ,
#        1.91919192, 1.93939394, 1.95959596, 1.97979798, 2.        ])

# %%
fig, ax= plt.subplots(figsize=(5,2.7))
ax.plot(x,x, label='linear')
ax.plot(x,x**2,label='quadratic')
ax.plot(x,x**3,label='cubic')
ax.set_xlabel('x label')
ax.set_ylabel('y label')
ax.set_title("Simple plot")
ax.legend()
plt.show()

# %% [markdown]
# ## pyplot 스타일
# * oo-스타일보다 사용법이 간단
# * 복잡한 그래프를 그릴 때는 적합하지 않음

# %%
x = np.linspace(0,2,100)

# %%
plt.figure(figsize=(5,2.7))
plt.plot(x, x, label="linear")
plt.plot(x, x**2, label="quadratic")
plt.plot(x, x**3, label="cubic")
plt.xlabel("x label")
plt.ylabel("y label")
plt.title("Simple plot pyplot style")
plt.legend()
plt.show()

# %% [markdown]
# ## 선 모양 바꾸기 set_linestyle(모양)

# %%
data1, data2, data3, data4 = np.random.randn(4,100)

# %%
data1
# Out:
# array([ 0.67428856, -0.66428656,  0.95617513,  0.60210112, -1.50458035,
#         0.43487998, -0.30358671, -0.67682316,  0.45438447,  0.5190034 ,
#         2.26890652,  0.80794038,  0.65941897,  1.61470794,  0.11172553,
#        -0.77262819, -0.31901449,  1.88957154, -0.46400763, -0.60126927,
#         0.69571964, -0.741873  , -0.82145002, -0.2312462 , -3.66941902,
#        -0.92165693,  0.35668298, -0.07245309, -1.13623919,  0.29345561,
#         0.2198624 ,  1.31516369, -0.27987528, -0.63639505, -3.02652207,
#        -0.03855562, -1.43665077, -1.14906768, -0.93886284, -0.25130368,
#         0.0342172 ,  1.37205382,  0.58019757, -0.54143255,  0.95101076,
#         1.88027105, -0.64805571, -0.83731363, -1.69939803,  0.27214278,
#         1.91909594, -0.90973656,  0.32694739,  1.10732975, -1.06598325,
#        -0.52757453, -0.30637871,  0.14407954, -0.67099105, -0.88824851,
#        -0.47141437, -0.23513139, -0.55259238,  0.2890318 ,  0.3809781 ,
#        -1.46420577,  0.60347725, -1.13367936, -0.70204319, -0.30053908,
#         0.27326806, -0.1168325 ,  0.77255951,  1.03860287, -0.38196612,
#         0.23906795,  0.5311896 , -0.82189006,  0.95087979, -0.56925411,
#        -0.06784358, -0.18520478, -0.35162899,  1.14693301,  0.23155825,
#         1.35288965,  1.00398924,  2.69874963,  0.92216248, -1.18955998,
#         0.21356441, -0.10022496,  0.48690008,  0.36792926,  0.82211594,
#        -0.50879236, -0.15704319, -1.6478679 ,  1.19150332, -0.21374441])

# %%
np.cumsum(np.arange(1,101))
# Out:
# array([   1,    3,    6,   10,   15,   21,   28,   36,   45,   55,   66,
#          78,   91,  105,  120,  136,  153,  171,  190,  210,  231,  253,
#         276,  300,  325,  351,  378,  406,  435,  465,  496,  528,  561,
#         595,  630,  666,  703,  741,  780,  820,  861,  903,  946,  990,
#        1035, 1081, 1128, 1176, 1225, 1275, 1326, 1378, 1431, 1485, 1540,
#        1596, 1653, 1711, 1770, 1830, 1891, 1953, 2016, 2080, 2145, 2211,
#        2278, 2346, 2415, 2485, 2556, 2628, 2701, 2775, 2850, 2926, 3003,
#        3081, 3160, 3240, 3321, 3403, 3486, 3570, 3655, 3741, 3828, 3916,
#        4005, 4095, 4186, 4278, 4371, 4465, 4560, 4656, 4753, 4851, 4950,
#        5050])

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
x = np.arange(len(data1))
ax.plot(x,np.cumsum(data1), color='blue', linewidth=3, linestyle=":")
i, = ax.plot(x, np.cumsum(data2),color='orange',linewidth=2)
i.set_linestyle(':')
plt.show()

# %% [markdown]
# 색 바꾸기 (facecolor, edgecolor)

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
ax.scatter(data1,data2, s=50, facecolor='C0', edgecolor='k')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
ax.plot(data1, 'o',label='data1')
ax.plot(data2, 'd',label='data2')
ax.plot(data3, 'v',label='data3')
ax.plot(data4, 's',label='data4')

ax.legend()
plt.show()

# %% [markdown]
# X축,Y축 이름, 눈금, 그래프 이름

# %%
mu, sigma = 115, 15
x = mu + sigma * np.random.randn(10000)
fig, ax = plt.subplots(figsize=(5,2.7))
n, bins, patches = ax.hist(x, 50, density=True, facecolor='C0', alpha=0.75)

ax.set_xlabel('Length [cm]')
ax.set_ylabel('Probability')
ax.set_title('Aardvark lengths\n (not really)')
ax.text(75, .025, r'$\mu=115, \ \sigma=15$')
ax.axis([55,175,0,0.03])
ax.grid(True)
plt.show()

# %%
fig, ax = plt.subplots(1,2, figsize=(5,2.7))
xdata = np.arange(len(data1))
data = 10**data1
ax[0].plot(xdata, data)
ax[1].plot(xdata, data)
ax[1].set_yscale('log')
plt.show()

# %% [markdown]
# 눈금자 단위 구간 설정하기

# %%
fig, ax = plt.subplots(2,1, figsize=(5,2.7))
ax[0].plot(xdata,data1)
ax[0].set_title('Automatic ticks')

ax[1].plot(xdata,data1)
ax[1].set_xticks(np.arange(0,100,30),['zero', '30','sixty','90'])
ax[1].set_yticks([-1.5,0,1.5])
ax[1].set_title('manual ticks')
plt.show()

# %% [markdown]
# 카테고리 막대 그래프 그리기

# %%
fig, ax = plt.subplots(figsize=(5,2.7))
categories = ['turnips', 'rutabaga', 'cucumber', 'pumkins']
ax.bar(categories, np.random.rand(len(categories)))
plt.show()

# %% [markdown]
# 그래프안에 그래프 겹쳐 그리기

# %%
t=np.arange(0.0,5.0,0.01)
s=np.cos(2*np.pi*t)
fig, (ax1,ax3) = plt.subplots(1,2, figsize=(5,2.7), layout='constrained')
l1, =ax1.plot(t,s)
ax2 = ax1.twinx()
l2, = ax2.plot(t,range(len(t)),'C1')
ax2.legend([l1,l2],['sine(left)','straigth(rigth)'])

ax3.plot(t,s)
ax3.set_xlabel('Angle [rad]')
ax4=ax3.secondary_xaxis('top', functions=(np.rad2deg, np.deg2rad))
ax4.set_xlabel('Angle [˚]')

plt.show()
