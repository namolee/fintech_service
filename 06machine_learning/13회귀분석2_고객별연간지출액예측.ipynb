# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("./data/ecommerce.csv")

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Email                 500 non-null    object
#  1   Address               500 non-null    object
#  2   Avatar                500 non-null    object
#  3   Avg. Session Length   500 non-null    float64
#  4   Time on App           500 non-null    float64
#  5   Time on Website       500 non-null    float64
#  6   Length of Membership  500 non-null    float64
#  7   Yearly Amount Spent   500 non-null    float64
# dtypes: float64(5), object(3)
# memory usage: 31.4+ KB

# %%
data['Address'].nunique()
# Out:
# 500

# %%
data['Email'].nunique()
# Out:
# 500

# %%
data['Avatar'].nunique()
# Out:
# 138

# %%
data['Avg. Session Length'].describe()
# Out:
# count    500.000000
# mean      33.053194
# std        0.992563
# min       29.532429
# 25%       32.341822
# 50%       33.082008
# 75%       33.711985
# max       36.139662
# Name: Avg. Session Length, dtype: float64

# %%
data['Time on App'].describe()
# Out:
# count    500.000000
# mean      12.052488
# std        0.994216
# min        8.508152
# 25%       11.388153
# 50%       11.983231
# 75%       12.753850
# max       15.126994
# Name: Time on App, dtype: float64

# %%
data['Time on Website'].describe()
# Out:
# count    500.000000
# mean      37.060445
# std        1.010489
# min       33.913847
# 25%       36.349257
# 50%       37.069367
# 75%       37.716432
# max       40.005182
# Name: Time on Website, dtype: float64

# %%
sns.boxplot(data[['Avg. Session Length', 'Time on App',
       'Time on Website', 'Length of Membership']])
# Out:
# <Axes: >

# %%
outlier = data.describe()

# %%
outlier
# Out:
#        Avg. Session Length  Time on App  Time on Website  \
# count           500.000000   500.000000       500.000000
# mean             33.053194    12.052488        37.060445
# std               0.992563     0.994216         1.010489
# min              29.532429     8.508152        33.913847
# 25%              32.341822    11.388153        36.349257
# 50%              33.082008    11.983231        37.069367
# 75%              33.711985    12.753850        37.716432
# max              36.139662    15.126994        40.005182
#
#        Length of Membership  Yearly Amount Spent
# count            500.000000           500.000000
# mean               3.533462           499.314038
# std                0.999278            79.314782
# min                0.269901           256.670582
# 25%                2.930450           445.038277
# 50%                3.533975           498.887875
# 75%                4.126502           549.313828
# max                6.922689           765.518462

# %%
outlier.loc['75%'] + (1.5 * (outlier.loc['75%']-outlier.loc['25%']))
# Out:
# Avg. Session Length      35.767230
# Time on App              14.802394
# Time on Website          39.767195
# Length of Membership      5.920580
# Yearly Amount Spent     705.727153
# dtype: float64

# %%
outlier.loc['25%'] - (1.5 * (outlier.loc['75%']-outlier.loc['25%']))
# Out:
# Avg. Session Length      30.286577
# Time on App               9.339609
# Time on Website          34.298495
# Length of Membership      1.136371
# Yearly Amount Spent     288.624951
# dtype: float64

# %%
data['Length of Membership'].describe()
# Out:
# count    500.000000
# mean       3.533462
# std        0.999278
# min        0.269901
# 25%        2.930450
# 50%        3.533975
# 75%        4.126502
# max        6.922689
# Name: Length of Membership, dtype: float64

# %%
data[data['Length of Membership']<=2.930450]
# Out:
#                           Email  \
# 1             hduke@hotmail.com
# 10        andrew06@peterson.com
# 14        taylormason@gmail.com
# 17     rebecca45@hale-bauer.biz
# 18      alejandro75@hotmail.com
# ..                          ...
# 489         tracy79@wheeler.net
# 492  davidsonkathleen@gmail.com
# 494       kellydeborah@chan.biz
# 498         cwilson@hotmail.com
# 499   hannahwilson@davidson.com
#
#                                                Address         Avatar  \
# 1       4547 Archer Common\nDiazchester, CA 06566-8576      DarkGreen
# 10   26104 Alexander Groves\nAlexandriaport, WY 282...         Tomato
# 14   7773 Powell Springs Suite 190\nSamanthaland, N...       DarkBlue
# 17                8982 Burton Row\nWilsonton, PW 88606      OliveDrab
# 18   64475 Andre Club Apt. 795\nPort Dannytown, PW ...           Cyan
# ..                                                 ...            ...
# 489  513 Moore Crescent Apt. 416\nAmandaberg, GU 03...        Magenta
# ...

# %%
# Length of Membership
# IQR = Q3-Q1= 4.126502 - 2.930450=1.1960520000000003

# %%
# Q1 - 1.5 * IQR = 1.1363747

# %%
data[data['Length of Membership']<=1.1363747]
# Out:
#                              Email  \
# 161       stevenking@patterson.com
# 173        fischermonica@gmail.com
# 225  alexandra26@summers-davis.com
# 303       brandon77@richardson.com
# 379               tsmith@yahoo.com
# 434          jordandavid@gmail.com
# 447         sharongraves@yahoo.com
#
#                                                Address      Avatar  \
# 161     94730 Martin Mount\nNew Matthew, VI 08142-6708   LightGray
# 173  9847 Michael Plaza Suite 837\nLake Christopher...        Navy
# 225              Unit 7032 Box 7016\nDPO AE 44749-2992        Navy
# 303   109 Jessica Manor\nNorth Patriciashire, PR 84726  GhostWhite
# 379  92028 Thomas Mountains Suite 044\nNew Matthew,...      Bisque
# 434  61502 Parker Vista Apt. 363\nJonesshire, GU 33532      Violet
# 447  73098 Ronald Port\nCliffordborough, MO 37479-9244       Wheat
#
#      Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# ...

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent'],
#       dtype='object')

# %%
data_corr = data[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']].corr()

# %%
data_corr
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data_corr, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap')
plt.show()

# %%
data2=data.copy()

# %%
data2 = data2[data2['Length of Membership'] >= 1.1363747]

# %%
data_corr2 = data2[['Avg. Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent']].corr()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(data_corr2, annot=True, cmap='coolwarm', fmt='.2f', linewidths=0.5)
plt.title('Correlation Heatmap2')
plt.show()

# %%
sorted(data.groupby('Avatar')['Yearly Amount Spent'].mean())
# Out:
# [386.6479469644702,
#  406.72210505413426,
#  419.63294156751954,
#  420.4525495603057,
#  425.7450920310528,
#  426.2491997948072,
#  430.6901723817928,
#  432.5880745084584,
#  434.0216997527185,
#  435.50696136042393,
#  435.53438736846255,
#  436.7205558562188,
#  436.93721042160973,
#  437.98836007828095,
#  441.0606890984435,
#  444.79794926582264,
#  449.6439355046467,
#  450.8085408678162,
#  452.62725499508304,
#  457.3757575535788,
#  457.84769594494855,
#  458.1109670290833,
#  459.73175574914313,
#  460.6932386153623,
#  464.4492715811856,
#  464.64799776409825,
#  465.219163427335,
#  465.94376701872335,
#  467.9852374676245,
#  469.89882388155974,
#  471.9477147236624,
#  472.1404800783187,
#  473.33094790940635,
#  473.62637580373496,
#  474.3145305571195,
#  475.2178389767011,
#  475.759067788328,
#  476.3801445434332,
#  476.7667241547634,
#  476.989533966875,
#  477.9051175131702,
#  478.33616628747586,
#  480.6720732687792,
#  481.0113949279279,
# ...

# %%
for i in data['Address'].str.split(','):
    print(i[-1].split()[-2])
# Out:
# MI
# CA
# DC
# OH
# PR
# MN
# WV
# AP
# SD
# AA
# WY
# AA
# MO
# MP
# ND
# OH
# GA
# PW
# PW
# MT
# KY
# AE
# AA
# AA
# WV
# ND
# VI
# TX
# MS
# SC
# WA
# DC
# AA
# NJ
# MS
# NH
# PW
# MI
# ME
# ID
# TN
# AK
# KY
# DE
# AE
# FM
# HI
# KS
# NC
# TN
# UT
# MS
# CA
# AL
# AA
# LA
# NE
# OR
# SD
# AA
# MN
# CT
# WA
# MA
# DE
# IN
# MS
# AZ
# AE
# MH
# NC
# AP
# HI
# NY
# MH
# CO
# CO
# AE
# IN
# IA
# GU
# IN
# IA
# AP
# NC
# WV
# TX
# AK
# VI
# AL
# AS
# AE
# RI
# SD
# VA
# NC
# DE
# AE
# AP
# MD
# FM
# WV
# OK
# WI
# VT
# FL
# IL
# MH
# MO
# MP
# NV
# TX
# PA
# NC
# AL
# MS
# ME
# MP
# ND
# AA
# VA
# DC
# OH
# KY
# IL
# KY
# SC
# AS
# AE
# AS
# WI
# OH
# NJ
# CO
# OR
# AP
# MT
# NM
# DE
# VT
# SC
# SC
# IN
# OR
# DC
# HI
# MA
# PA
# MI
# CO
# NM
# DE
# MH
# SC
# UT
# WY
# MP
# AP
# VI
# NJ
# AE
# VI
# PA
# AA
# AP
# MH
# ND
# PA
# MT
# MO
# SD
# KY
# WI
# NV
# PR
# PA
# OR
# DE
# TX
# AK
# AR
# OR
# FL
# ME
# NC
# VT
# CA
# PR
# FL
# RI
# NJ
# IN
# RI
# NC
# SD
# SC
# NH
# VT
# PR
# WY
# ...

# %%
data['state_name']=data['Address'].apply(lambda x : ((x.split(','))[-1].split())[-2])

# %%
data
# Out:
#                              Email  \
# 0        mstephenson@fernandez.com
# 1                hduke@hotmail.com
# 2                 pallen@yahoo.com
# 3          riverarebecca@gmail.com
# 4    mstephens@davidson-herman.com
# ..                             ...
# 495   lewisjessica@craig-evans.com
# 496            katrina56@gmail.com
# 497             dale88@hotmail.com
# 498            cwilson@hotmail.com
# 499      hannahwilson@davidson.com
#
#                                                Address            Avatar  \
# 0         835 Frank Tunnel\nWrightmouth, MI 82180-9605            Violet
# 1       4547 Archer Common\nDiazchester, CA 06566-8576         DarkGreen
# 2    24645 Valerie Unions Suite 582\nCobbborough, D...            Bisque
# 3     1414 David Throughway\nPort Jason, OH 22070-1220       SaddleBrown
# 4    14023 Rodriguez Passage\nPort Jacobville, PR 3...  MediumAquaMarine
# ..                                                 ...               ...
# ...

# %%
data.groupby('state_name')['Yearly Amount Spent'].describe().sort_values(by='mean')
# Out:
#             count        mean         std         min         25%         50%  \
# state_name
# PW            6.0  413.315738   41.089085  347.776927  400.548738  409.858739
# GU            6.0  414.701360  100.849577  304.135592  342.417144  397.705547
# NH            7.0  448.609303   68.641665  352.550108  402.141196  461.790959
# NV            6.0  452.483974   84.186395  298.762008  439.175327  468.934705
# LA            6.0  461.629503   77.256200  368.654785  406.529416  464.109429
# ...           ...         ...         ...         ...         ...         ...
# MN           11.0  546.266279   81.288184  401.033135  485.806863  583.977802
# AR            6.0  550.633210   28.390539  517.165136  527.858082  553.068623
# IN            7.0  558.303399  122.284826  462.897636  470.345119  488.786061
# MP            5.0  560.966458   36.412356  503.175085  549.008227  573.415867
# UT            5.0  566.491138  119.244259  392.810345  544.409272  573.847438
#
# ...

# %% [markdown]
# 선형성, 독립성, 등분산성, 정규성

# %%
data.columns
# Out:
# Index(['Email', 'Address', 'Avatar', 'Avg. Session Length', 'Time on App',
#        'Time on Website', 'Length of Membership', 'Yearly Amount Spent',
#        'state_name'],
#       dtype='object')

# %%
data.corr(numeric_only=True)
# Out:
#                       Avg. Session Length  Time on App  Time on Website  \
# Avg. Session Length              1.000000    -0.027826        -0.034987
# Time on App                     -0.027826     1.000000         0.082388
# Time on Website                 -0.034987     0.082388         1.000000
# Length of Membership             0.060247     0.029143        -0.047582
# Yearly Amount Spent              0.355088     0.499328        -0.002641
#
#                       Length of Membership  Yearly Amount Spent
# Avg. Session Length               0.060247             0.355088
# Time on App                       0.029143             0.499328
# Time on Website                  -0.047582            -0.002641
# Length of Membership              1.000000             0.809084
# Yearly Amount Spent               0.809084             1.000000

# %%
sns.heatmap(data.corr(numeric_only=True), annot=True, linewidths=1)
# Out:
# <Axes: >

# %%
data = data.drop(['Email', 'Address', 'Avatar'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 data = data.drop(['Email', 'Address', 'Avatar'], axis=1)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\pandas\core\frame.py:5581, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5433 def drop(
#    5434     self,
#    5435     labels: IndexLabel | None = None,
#    (...)
#    5442     errors: IgnoreRaise = "raise",
#    5443 ) -> DataFrame | None:
#    5444     """
#    5445     Drop specified labels from rows or columns.
#    5446
#    (...)
#    5579             weight  1.0     0.8
#    5580     """
# -> 5581     return super().drop(
#    5582         labels=labels,
#    5583         axis=axis,
#    5584         index=index,
#    5585         columns=columns,
#    5586         level=level,
#    5587         inplace=inplace,
#    5588         errors=errors,
# ...

# %%
data.head()
# Out:
#    Avg. Session Length  Time on App  Time on Website  Length of Membership  \
# 0            34.497268    12.655651        39.577668              4.082621
# 1            31.926272    11.109461        37.268959              2.664034
# 2            33.000915    11.330278        37.110597              4.104543
# 3            34.305557    13.717514        36.721283              3.120179
# 4            33.330673    12.795189        37.536653              4.446308
#
#    Yearly Amount Spent state_name
# 0           587.951054         MI
# 1           392.204933         CA
# 2           487.547505         DC
# 3           581.852344         OH
# 4           599.406092         PR

# %%
data.columns=[col.replace(' ','').replace('.','') for col in data.columns]

# %%
data
# Out:
#      AvgSessionLength  TimeonApp  TimeonWebsite  LengthofMembership  \
# 0           34.497268  12.655651      39.577668            4.082621
# 1           31.926272  11.109461      37.268959            2.664034
# 2           33.000915  11.330278      37.110597            4.104543
# 3           34.305557  13.717514      36.721283            3.120179
# 4           33.330673  12.795189      37.536653            4.446308
# ..                ...        ...            ...                 ...
# 495         33.237660  13.566160      36.417985            3.746573
# 496         34.702529  11.695736      37.190268            3.576526
# 497         32.646777  11.499409      38.332576            4.958264
# 498         33.322501  12.391423      36.840086            2.336485
# 499         33.715981  12.418808      35.771016            2.735160
#
#      YearlyAmountSpent state_name
# 0           587.951054         MI
# 1           392.204933         CA
# 2           487.547505         DC
# ...

# %%
X=data.drop('YearlyAmountSpent',axis=1)
y=data['YearlyAmountSpent']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.2, random_state=7)

# %% [markdown]
# 다중선형회귀분석하기

# %%
# statsmodels R 문법
from statsmodels.formula.api import ols

# %%
train_data = pd.concat([X_train, y_train], axis=1)
train_data.head()
# Out:
#      AvgSessionLength  TimeonApp  TimeonWebsite  LengthofMembership  \
# 342         32.342796  11.409645      35.777782            3.872432
# 359         32.054262  13.149670      37.650400            4.195614
# 109         33.356874  13.452129      38.503009            3.318822
# 50          33.256335  13.858062      37.780265            5.976768
# 452         33.552108  11.120871      36.808376            4.027814
#
#     state_name  YearlyAmountSpent
# 342         MT         486.083426
# 359         ME         561.874658
# 109         MP         549.008227
# 50          UT         725.584814
# 452         ME         521.195311

# %%
train_data.columns
# Out:
# Index(['AvgSessionLength', 'TimeonApp', 'TimeonWebsite', 'LengthofMembership',
#        'state_name', 'YearlyAmountSpent'],
#       dtype='object')

# %%
lm=ols('YearlyAmountSpent ~ AvgSessionLength + TimeonApp + TimeonWebsite + LengthofMembership+ state_name',data=train_data).fit()

# %%
lm.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      YearlyAmountSpent   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     389.1
# Date:                Thu, 29 Aug 2024   Prob (F-statistic):          4.36e-279
# Time:                        15:07:59   Log-Likelihood:                -1449.5
# No. Observations:                 400   AIC:                             3031.
# Df Residuals:                     334   BIC:                             3294.
# Df Model:                          65
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...

# %% [markdown]
# Prob (F-statistic):	4.36e-279 : 통계적으로 유의미
# Adj. R-squared:	0.984
# P>|t| 값이 0.05보다 작은것:

# %%
# statsmodels의 python문법
import statsmodels.api as sm

# %%
# 상수항 추가
X_train = sm.add_constant(X_train)
X_test = sm.add_constant(X_test)

# %%
X_train.head(2)
# Out:
#      const  AvgSessionLength  TimeonApp  TimeonWebsite  LengthofMembership  \
# 342    1.0         32.342796  11.409645      35.777782            3.872432
# 359    1.0         32.054262  13.149670      37.650400            4.195614
#
#     state_name
# 342         MT
# 359         ME

# %%
X_train = pd.get_dummies(X_train)
X_train
# Out:
#      const  AvgSessionLength  TimeonApp  TimeonWebsite  LengthofMembership  \
# 342    1.0         32.342796  11.409645      35.777782            3.872432
# 359    1.0         32.054262  13.149670      37.650400            4.195614
# 109    1.0         33.356874  13.452129      38.503009            3.318822
# 50     1.0         33.256335  13.858062      37.780265            5.976768
# 452    1.0         33.552108  11.120871      36.808376            4.027814
# ..     ...               ...        ...            ...                 ...
# 211    1.0         34.081646  12.104542      36.059646            3.974522
# 67     1.0         32.805220  11.835476      36.375066            3.439591
# 25     1.0         33.029332  11.765813      37.738525            2.721736
# 196    1.0         32.733224  11.818572      37.102031            1.503854
# 175    1.0         33.308572  11.691686      37.480912            1.715777
#
#      state_name_AA  state_name_AE  state_name_AK  state_name_AL  \
# ...

# %%
X_test = pd.get_dummies(X_test)

# %%
X_train=X_train.astype('float')
X_test=X_test.astype('float')

# %%
tr = sm.OLS(y_train, X_train).fit()

# %%
tr.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:      YearlyAmountSpent   R-squared:                       0.987
# Model:                            OLS   Adj. R-squared:                  0.984
# Method:                 Least Squares   F-statistic:                     389.1
# Date:                Thu, 29 Aug 2024   Prob (F-statistic):          4.36e-279
# Time:                        15:37:30   Log-Likelihood:                -1449.5
# No. Observations:                 400   AIC:                             3031.
# Df Residuals:                     334   BIC:                             3294.
# Df Model:                          65
# Covariance Type:            nonrobust
# ...
#                          coef    std err          t      P>|t|      [0.025      0.975]
# --------------------------------------------------------------------------------------
# ...
