# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs
import time

# %%
url="https://kind.krx.co.kr/corpgeneral/corpList.do"
payload=dict(method='searchCorpList',pageIndex=1,currentPageSize=15,comAbbrv='',beginIndex='',orderMode=3,orderStat='D',isurCd='',repIsuSrtCd='',searchCodeType='',marketType='',searchType=13,industry='',fiscalYearEnd='all',comAbbrvTmp='',location='all')
r=requests.get(url, params=payload)
print(r.status_code)
print(r.text)

soup=bs(r.text,'lxml')
# Out:
# 200
#
#
#
#
#
#
#
#
# <section class="scrarea type-00">
# 	<table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="*" />
# 			<col width="15%" />
# 			<col width="20%" />
# 			<col width="11%" />
# 			<col width="8%" />
# 			<col width="10%" />
# 			<col width="8%" />
# 			<col width="12%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first" id="title-contents">
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
# 			<tr
# 					class="first"
# 			>
# 				<td class="first" title="엔에이치기업인수목적31호(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('48189'); return false;" title='엔에이치스팩31호'> 엔에이치스팩31호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# 				<td class="txc">2024-07-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이시형">이시형</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에스케이증권제13호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47395'); return false;" title='SK증권제13호스팩'> SK증권제13호스팩</a> <img src='/images/common/icn_t_joo.gif' class='vmiddle legend' alt='투자주의종목'/> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="임율표">임율표</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)엑셀세라퓨틱스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('37311'); return false;" title='엑셀세라퓨틱스'> 엑셀세라퓨틱스</a> </td>
# 				<td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# 				<td class="textOverflow" title="CellCor SFD/CD(세포배양배지)">CellCor SFD/CD(세포배양배지)</td>
# 				<td class="txc">2024-07-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이의일">이의일</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="이베스트기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47811'); return false;" title='이베스트스팩6호'> 이베스트스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-12</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박용">박용</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)시프트업"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('46287'); return false;" title='시프트업'> 시프트업</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 소프트웨어">게임 소프트웨어</td>
# 				<td class="txc">2024-07-11</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김형태">김형태</td>
# 				<td class="txc">
#
# 						<a href="http://shiftup.co.kr" class="btn ico homepage" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)하스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45033'); return false;" title='하스'> 하스</a> </td>
# 				<td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
# 				<td class="textOverflow" title="리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관">리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관</td>
# 				<td class="txc">2024-07-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김용수">김용수</td>
# 				<td class="txc">
#
# 						<a href="http://www.hassbio.com" class="btn ico homepage" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">강원특별자치도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)이노스페이스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46235'); return false;" title='이노스페이스'> 이노스페이스</a> </td>
# 				<td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# 				<td class="textOverflow" title="소형발사체, 로켓추진기관, 과학로켓, 시험평가용역">소형발사체, 로켓추진기관, 과학로켓, 시험평가용역</td>
# 				<td class="txc">2024-07-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김수종">김수종</td>
# 				<td class="txc">
#
# 						<a href="http://www.innospc.com/" class="btn ico homepage" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">세종특별자치시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)신한글로벌액티브위탁관리부동산투자회사"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('48185'); return false;" title='신한글로벌액티브리츠'> 신한글로벌액티브리츠</a> </td>
# 				<td class="textOverflow" title="신탁업 및 집합투자업">신탁업 및 집합투자업</td>
# 				<td class="textOverflow" title="신탁 및 집합투자">신탁 및 집합투자</td>
# 				<td class="txc">2024-07-01</td>
# 				<td class="txc">02월</td>
# 				<td class="txc" title="김선영">김선영</td>
# 				<td class="txc">
#
# 						<a href="http://shglobalreit.com" class="btn ico homepage" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이치브이엠"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('29531'); return false;" title='에이치브이엠'> 에이치브이엠</a> </td>
# 				<td class="textOverflow" title="1차 비철금속 제조업">1차 비철금속 제조업</td>
# 				<td class="textOverflow" title="Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등">Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="문승호">문승호</td>
# 				<td class="txc">
#
# 						<a href="http://hvm.co.kr/" class="btn ico homepage" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)팡스카이"><img src='/images/common/icn_t_konex.gif' class='vmiddle legend' alt='코넥스'> <a id="companysum" href="#companysum" onclick="companysummary_open('26635'); return false;" title='팡스카이'> 팡스카이</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 개발 및 리퍼블리싱">게임 개발 및 리퍼블리싱</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조호현, 이병진">조호현..</td>
# 				<td class="txc">
#
# 						<a href="http://www.panggame.com/" class="btn ico homepage" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하이젠알앤엠 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('16019'); return false;" title='하이젠알앤엠'> 하이젠알앤엠</a> </td>
# 				<td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# 				<td class="textOverflow" title="전동기 및 발전기 (범용모터, 서보모터)">전동기 및 발전기 (범용모터, 서보모터)</td>
# 				<td class="txc">2024-06-27</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김재학">김재학</td>
# 				<td class="txc">
#
# 						<a href="http://higenrnm.com" class="btn ico homepage" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상남도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="한국제15호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47988'); return false;" title='한국제15호스팩'> 한국제15호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="유한">유한</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에스오에스랩"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46408'); return false;" title='에스오에스랩'> 에스오에스랩</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="산업용 및 차량용 라이다(LiDAR)">산업용 및 차량용 라이다(LiDAR)</td>
# 				<td class="txc">2024-06-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정지성">정지성</td>
# 				<td class="txc">
#
# 						<a href="http://soslab.co" class="btn ico homepage" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">광주광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47844'); return false;" title='미래에셋비전스팩6호'> 미래에셋비전스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정명훈">정명훈</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에이치엠씨아이비제7호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47734'); return false;" title='에이치엠씨제7호스팩'> 에이치엠씨제7호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기타금융">기타금융</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강신명">강신명</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
#
#
#
# 		</tbody>
# 	</table>
# </section>
#
# <!-- 페이징 START -->
# <section class="paging-group">
# 	<div class='paging type-00'><a href='#prevPage10' class='pprev' onclick='return false;'><span>이전10개 페이지</span></a><a href='#prevPage' class='prev' onclick='return false;'><span>이전 페이지</span></a>
# <a href='#page_link_1' class='active' onclick='return false;'>1</a><a href='#page_link_2' onclick="fnPageGo('2');return false;">2</a><a href='#page_link_3' onclick="fnPageGo('3');return false;">3</a><a href='#page_link_4' onclick="fnPageGo('4');return false;">4</a><a href='#page_link_5' onclick="fnPageGo('5');return false;">5</a><a href='#page_link_6' onclick="fnPageGo('6');return false;">6</a><a href='#page_link_7' onclick="fnPageGo('7');return false;">7</a><a href='#page_link_8' onclick="fnPageGo('8');return false;">8</a><a href='#page_link_9' onclick="fnPageGo('9');return false;">9</a><a href='#page_link_10' onclick="fnPageGo('10');return false;">10</a>
# <a href='#nextPage' class='next' onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a href='#nextPage10' class='nnext' onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,704</em>건 : <strong>1</strong>/181&nbsp;&nbsp;&nbsp;
# <select id='currentPageSize' name='currentPageSize'>
# <option value='15'  selected='selected'>15건</option>
# <option value='30'  >30건</option>
# <option value='50'  >50건</option>
# <option value='100' >100건</option>
# </select>&nbsp;&nbsp;<a href='#' onclick="fnSearch1();return false;" class='btn-sprite btn-go vmiddle' title='GO'><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
#
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %%
soup.select("tbody tr") # 한 페이지에 나와있는 기업목록. 인덱스로 접근 가능
# Out:
# <tr class="first">
# <td class="first" title="엔에이치기업인수목적31호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48189'); return false;" title="엔에이치스팩31호"> 엔에이치스팩31호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# <td class="txc">2024-07-26</td>
# <td class="txc">12월</td>
# <td class="txc" title="이시형">이시형</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>

# %%
cor=soup.select("tbody tr")[0]
cor
# Out:
# <tr class="first">
# <td class="first" title="엔에이치기업인수목적31호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48189'); return false;" title="엔에이치스팩31호"> 엔에이치스팩31호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# <td class="txc">2024-07-26</td>
# <td class="txc">12월</td>
# <td class="txc" title="이시형">이시형</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>

# %%
cor.select("td")[0].text
# Out:
# '  엔에이치스팩31호 '

# %%
cor.select_one("td").text
# Out:
# '  엔에이치스팩31호 '

# %%
cor.select_one(".first").text.strip()
# Out:
# '엔에이치스팩31호'

# %%
cor.select(".first").text # select는 전체를 받아오려고 하기 때문에 리스트에 받아온다. 자료형이 리스트이기 때문에 .text가 안된다
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[109], line 1
# ----> 1 cor.select(".first").text
#
# File ~\miniforge3\envs\fintech\lib\site-packages\bs4\element.py:2433, in ResultSet.__getattr__(self, key)
#    2431 def __getattr__(self, key):
#    2432     """Raise a helpful exception to explain a common code fix."""
# -> 2433     raise AttributeError(
#    2434         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2435     )
#
# AttributeError: ResultSet object has no attribute 'text'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
cor.select_one(".textOverflow").text.strip()
# Out:
# '금융 지원 서비스업'

# %%
cor_infos=cor.select("td")
cor_infos
# Out:
# [<td class="first" title="엔에이치기업인수목적31호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48189'); return false;" title="엔에이치스팩31호"> 엔에이치스팩31호</a> </td>,
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>,
#  <td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>,
#  <td class="txc">2024-07-26</td>,
#  <td class="txc">12월</td>,
#  <td class="txc" title="이시형">이시형</td>,
#  <td class="txc">
#  </td>,
#  <td class="txc">서울특별시</td>]

# %%
cor.select(".txc")
# Out:
# [<td class="txc">2024-07-26</td>,
#  <td class="txc">12월</td>,
#  <td class="txc" title="이시형">이시형</td>,
#  <td class="txc">
#  </td>,
#  <td class="txc">서울특별시</td>]

# %%
col_list=[]
col_list.append(soup.select_one("table.list.type-00.tmt30")['summary'])
col_list
# Out:
# ['회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역']

# %%
col_list=[]
col_list.append(soup.select_one("table.list.type-00.tmt30")['class'])
col_list

# %%
result={}
for item in soup.select("tbody"):
    for cor_info in (item):
        print(cor_info.text.strip())
# Out:
# 엔에이치스팩31호
# 금융 지원 서비스업
# 금융지원서비스업
# 2024-07-26
# 12월
# 이시형
#
#
# 서울특별시
#
# SK증권제13호스팩
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-07-25
# 12월
# 임율표
#
#
# 서울특별시
#
# 엑셀세라퓨틱스
# 기초 의약물질 제조업
# CellCor SFD/CD(세포배양배지)
# 2024-07-15
# 12월
# 이의일
#
#
# 서울특별시
#
# 이베스트스팩6호
# 금융 지원 서비스업
# 기업인수목적 주식회사
# 2024-07-12
# 12월
# 박용
#
#
# 서울특별시
#
# 시프트업
# 소프트웨어 개발 및 공급업
# 게임 소프트웨어
# 2024-07-11
# 12월
# 김형태
#
# 홈페이지 보기
#
# 서울특별시
#
# 하스
# 의료용품 및 기타 의약 관련제품 제조업
# 리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관
# 2024-07-03
# 12월
# 김용수
#
# 홈페이지 보기
#
# 강원특별자치도
#
# 이노스페이스
# 항공기,우주선 및 부품 제조업
# 소형발사체, 로켓추진기관, 과학로켓, 시험평가용역
# 2024-07-02
# 12월
# 김수종
#
# 홈페이지 보기
#
# 세종특별자치시
#
# 신한글로벌액티브리츠
# 신탁업 및 집합투자업
# 신탁 및 집합투자
# 2024-07-01
# 02월
# 김선영
#
# 홈페이지 보기
#
# 서울특별시
#
# 에이치브이엠
# 1차 비철금속 제조업
# Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등
# 2024-06-28
# 12월
# 문승호
#
# 홈페이지 보기
#
# 경기도
#
# 팡스카이
# 소프트웨어 개발 및 공급업
# 게임 개발 및 리퍼블리싱
# 2024-06-28
# 12월
# 조호현..
#
# 홈페이지 보기
#
# 서울특별시
#
# 하이젠알앤엠
# 전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 전동기 및 발전기 (범용모터, 서보모터)
# 2024-06-27
# 12월
# 김재학
#
# 홈페이지 보기
#
# 경상남도
#
# 한국제15호스팩
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-26
# 12월
# 유한
#
#
# 서울특별시
#
# 에스오에스랩
# 측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 산업용 및 차량용 라이다(LiDAR)
# 2024-06-25
# 12월
# 정지성
#
# 홈페이지 보기
#
# 광주광역시
#
# 미래에셋비전스팩6호
# 금융 지원 서비스업
# 기업인수합병
# 2024-06-24
# 12월
# 정명훈
#
#
# 서울특별시
#
# 에이치엠씨제7호스팩
# 금융 지원 서비스업
# 기타금융
# 2024-06-24
# 12월
# 강신명
#
#
# 서울특별시

# %%
result={}
for item in soup.select("tbody"):
    for idx,cor_info in enumerate(item):
        result.setdefault(col_list[idx],[]).append(cor_info.text.strip())

# %% [markdown]
# ==============================================================

# %%
import os
import requests
import pandas as pd
from bs4 import BeautifulSoup as bs

# %%
url="https://kind.krx.co.kr/corpgeneral/corpList.do"
payload=dict(method='searchCorpList',pageIndex=1,currentPageSize=15,comAbbrv='',beginIndex='',orderMode=3,orderStat='D',isurCd='',repIsuSrtCd='',searchCodeType='',marketType='',searchType=13,industry='',fiscalYearEnd='all',comAbbrvTmp='',location='all')
r=requests.get(url, params=payload)
print(r.status_code)
print(r.text)

soup=bs(r.text,'lxml')
# Out:
# 200
#
#
#
#
#
#
#
#
# <section class="scrarea type-00">
# 	<table class="list type-00 tmt30" summary="회사명, 업종, 주요제품, 상장일, 결산월, 대표자명, 홈페이지, 지역">
# 		<caption>목록</caption>
# 		<colgroup>
# 			<col width="*" />
# 			<col width="15%" />
# 			<col width="20%" />
# 			<col width="11%" />
# 			<col width="8%" />
# 			<col width="10%" />
# 			<col width="8%" />
# 			<col width="12%" />
# 		</colgroup>
# 		<thead>
# 			<tr class="first" id="title-contents">
# 			</tr>
# 		</thead>
# 		<tbody>
#
#
#
# 			<tr
# 					class="first"
# 			>
# 				<td class="first" title="엔에이치기업인수목적31호(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('48189'); return false;" title='엔에이치스팩31호'> 엔에이치스팩31호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# 				<td class="txc">2024-07-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이시형">이시형</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에스케이증권제13호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47395'); return false;" title='SK증권제13호스팩'> SK증권제13호스팩</a> <img src='/images/common/icn_t_joo.gif' class='vmiddle legend' alt='투자주의종목'/> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="임율표">임율표</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)엑셀세라퓨틱스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('37311'); return false;" title='엑셀세라퓨틱스'> 엑셀세라퓨틱스</a> </td>
# 				<td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
# 				<td class="textOverflow" title="CellCor SFD/CD(세포배양배지)">CellCor SFD/CD(세포배양배지)</td>
# 				<td class="txc">2024-07-15</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="이의일">이의일</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="이베스트기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47811'); return false;" title='이베스트스팩6호'> 이베스트스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
# 				<td class="txc">2024-07-12</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="박용">박용</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)시프트업"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('46287'); return false;" title='시프트업'> 시프트업</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 소프트웨어">게임 소프트웨어</td>
# 				<td class="txc">2024-07-11</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김형태">김형태</td>
# 				<td class="txc">
#
# 						<a href="http://shiftup.co.kr" class="btn ico homepage" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)하스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('45033'); return false;" title='하스'> 하스</a> </td>
# 				<td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
# 				<td class="textOverflow" title="리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관">리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관</td>
# 				<td class="txc">2024-07-03</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김용수">김용수</td>
# 				<td class="txc">
#
# 						<a href="http://www.hassbio.com" class="btn ico homepage" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">강원특별자치도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)이노스페이스"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46235'); return false;" title='이노스페이스'> 이노스페이스</a> </td>
# 				<td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
# 				<td class="textOverflow" title="소형발사체, 로켓추진기관, 과학로켓, 시험평가용역">소형발사체, 로켓추진기관, 과학로켓, 시험평가용역</td>
# 				<td class="txc">2024-07-02</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김수종">김수종</td>
# 				<td class="txc">
#
# 						<a href="http://www.innospc.com/" class="btn ico homepage" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">세종특별자치시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)신한글로벌액티브위탁관리부동산투자회사"><img src='/images/common/icn_t_yu.gif' class='vmiddle legend' alt='유가증권'> <a id="companysum" href="#companysum" onclick="companysummary_open('48185'); return false;" title='신한글로벌액티브리츠'> 신한글로벌액티브리츠</a> </td>
# 				<td class="textOverflow" title="신탁업 및 집합투자업">신탁업 및 집합투자업</td>
# 				<td class="textOverflow" title="신탁 및 집합투자">신탁 및 집합투자</td>
# 				<td class="txc">2024-07-01</td>
# 				<td class="txc">02월</td>
# 				<td class="txc" title="김선영">김선영</td>
# 				<td class="txc">
#
# 						<a href="http://shglobalreit.com" class="btn ico homepage" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에이치브이엠"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('29531'); return false;" title='에이치브이엠'> 에이치브이엠</a> </td>
# 				<td class="textOverflow" title="1차 비철금속 제조업">1차 비철금속 제조업</td>
# 				<td class="textOverflow" title="Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등">Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="문승호">문승호</td>
# 				<td class="txc">
#
# 						<a href="http://hvm.co.kr/" class="btn ico homepage" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경기도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)팡스카이"><img src='/images/common/icn_t_konex.gif' class='vmiddle legend' alt='코넥스'> <a id="companysum" href="#companysum" onclick="companysummary_open('26635'); return false;" title='팡스카이'> 팡스카이</a> </td>
# 				<td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
# 				<td class="textOverflow" title="게임 개발 및 리퍼블리싱">게임 개발 및 리퍼블리싱</td>
# 				<td class="txc">2024-06-28</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="조호현, 이병진">조호현..</td>
# 				<td class="txc">
#
# 						<a href="http://www.panggame.com/" class="btn ico homepage" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="하이젠알앤엠 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('16019'); return false;" title='하이젠알앤엠'> 하이젠알앤엠</a> </td>
# 				<td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
# 				<td class="textOverflow" title="전동기 및 발전기 (범용모터, 서보모터)">전동기 및 발전기 (범용모터, 서보모터)</td>
# 				<td class="txc">2024-06-27</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="김재학">김재학</td>
# 				<td class="txc">
#
# 						<a href="http://higenrnm.com" class="btn ico homepage" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">경상남도</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="한국제15호기업인수목적 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47988'); return false;" title='한국제15호스팩'> 한국제15호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-26</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="유한">유한</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="(주)에스오에스랩"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('46408'); return false;" title='에스오에스랩'> 에스오에스랩</a> </td>
# 				<td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
# 				<td class="textOverflow" title="산업용 및 차량용 라이다(LiDAR)">산업용 및 차량용 라이다(LiDAR)</td>
# 				<td class="txc">2024-06-25</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정지성">정지성</td>
# 				<td class="txc">
#
# 						<a href="http://soslab.co" class="btn ico homepage" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
#
# 				</td>
# 				<td class="txc">광주광역시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="미래에셋비전기업인수목적6호 주식회사"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47844'); return false;" title='미래에셋비전스팩6호'> 미래에셋비전스팩6호</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기업인수합병">기업인수합병</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="정명훈">정명훈</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
# 			<tr
#
# 			>
# 				<td class="first" title="에이치엠씨아이비제7호기업인수목적(주)"><img src='/images/common/icn_t_ko.gif' class='vmiddle legend' alt='코스닥'> <a id="companysum" href="#companysum" onclick="companysummary_open('47734'); return false;" title='에이치엠씨제7호스팩'> 에이치엠씨제7호스팩</a> </td>
# 				<td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# 				<td class="textOverflow" title="기타금융">기타금융</td>
# 				<td class="txc">2024-06-24</td>
# 				<td class="txc">12월</td>
# 				<td class="txc" title="강신명">강신명</td>
# 				<td class="txc">
#
# 				</td>
# 				<td class="txc">서울특별시</td>
# 			</tr>
#
#
#
#
# 		</tbody>
# 	</table>
# </section>
#
# <!-- 페이징 START -->
# <section class="paging-group">
# 	<div class='paging type-00'><a href='#prevPage10' class='pprev' onclick='return false;'><span>이전10개 페이지</span></a><a href='#prevPage' class='prev' onclick='return false;'><span>이전 페이지</span></a>
# <a href='#page_link_1' class='active' onclick='return false;'>1</a><a href='#page_link_2' onclick="fnPageGo('2');return false;">2</a><a href='#page_link_3' onclick="fnPageGo('3');return false;">3</a><a href='#page_link_4' onclick="fnPageGo('4');return false;">4</a><a href='#page_link_5' onclick="fnPageGo('5');return false;">5</a><a href='#page_link_6' onclick="fnPageGo('6');return false;">6</a><a href='#page_link_7' onclick="fnPageGo('7');return false;">7</a><a href='#page_link_8' onclick="fnPageGo('8');return false;">8</a><a href='#page_link_9' onclick="fnPageGo('9');return false;">9</a><a href='#page_link_10' onclick="fnPageGo('10');return false;">10</a>
# <a href='#nextPage' class='next' onclick="fnPageGo('2');return false;"><span>다음 페이지</span></a><a href='#nextPage10' class='nnext' onclick="fnPageGo('11');return false;"><span>다음10개 페이지</span></a></div><div class="info type-00">
# 전체 <em>2,704</em>건 : <strong>1</strong>/181&nbsp;&nbsp;&nbsp;
# <select id='currentPageSize' name='currentPageSize'>
# <option value='15'  selected='selected'>15건</option>
# <option value='30'  >30건</option>
# <option value='50'  >50건</option>
# <option value='100' >100건</option>
# </select>&nbsp;&nbsp;<a href='#' onclick="fnSearch1();return false;" class='btn-sprite btn-go vmiddle' title='GO'><span>GO</span></a>
# </div>
# </section>
# <!-- 페이징 END -->
#
# <script type="text/JavaScript">
# $(document).ready(function(){
# 	fn_InitTitle("회사명,업종,주요제품,상장일,결산월,대표자명,홈페이지,지역", "true,false,false,true,false,false,false,false");
# });
# </script>

# %%
soup.select('tr')
# Out:
# [<tr class="first" id="title-contents">
#  </tr>,
#  <tr class="first">
#  <td class="first" title="엔에이치기업인수목적31호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48189'); return false;" title="엔에이치스팩31호"> 엔에이치스팩31호</a> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
#  <td class="txc">2024-07-26</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="이시형">이시형</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="에스케이증권제13호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47395'); return false;" title="SK증권제13호스팩"> SK증권제13호스팩</a> <img alt="투자주의종목" class="vmiddle legend" src="/images/common/icn_t_joo.gif"/> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
#  <td class="txc">2024-07-25</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="임율표">임율표</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)엑셀세라퓨틱스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('37311'); return false;" title="엑셀세라퓨틱스"> 엑셀세라퓨틱스</a> </td>
#  <td class="textOverflow" title="기초 의약물질 제조업">기초 의약물질 제조업</td>
#  <td class="textOverflow" title="CellCor SFD/CD(세포배양배지)">CellCor SFD/CD(세포배양배지)</td>
#  <td class="txc">2024-07-15</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="이의일">이의일</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="이베스트기업인수목적6호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47811'); return false;" title="이베스트스팩6호"> 이베스트스팩6호</a> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="기업인수목적 주식회사">기업인수목적 주식회사</td>
#  <td class="txc">2024-07-12</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="박용">박용</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)시프트업"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46287'); return false;" title="시프트업"> 시프트업</a> </td>
#  <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
#  <td class="textOverflow" title="게임 소프트웨어">게임 소프트웨어</td>
#  <td class="txc">2024-07-11</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="김형태">김형태</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://shiftup.co.kr" target="_blank" title="http://shiftup.co.kr"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)하스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('45033'); return false;" title="하스"> 하스</a> </td>
#  <td class="textOverflow" title="의료용품 및 기타 의약 관련제품 제조업">의료용품 및 기타 의약 관련제품 제조업</td>
#  <td class="textOverflow" title="리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관">리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코니아 유치관</td>
#  <td class="txc">2024-07-03</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="김용수">김용수</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://www.hassbio.com" target="_blank" title="http://www.hassbio.com"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">강원특별자치도</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)이노스페이스"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46235'); return false;" title="이노스페이스"> 이노스페이스</a> </td>
#  <td class="textOverflow" title="항공기,우주선 및 부품 제조업">항공기,우주선 및 부품 제조업</td>
#  <td class="textOverflow" title="소형발사체, 로켓추진기관, 과학로켓, 시험평가용역">소형발사체, 로켓추진기관, 과학로켓, 시험평가용역</td>
#  <td class="txc">2024-07-02</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="김수종">김수종</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://www.innospc.com/" target="_blank" title="http://www.innospc.com/"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">세종특별자치시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)신한글로벌액티브위탁관리부동산투자회사"><img alt="유가증권" class="vmiddle legend" src="/images/common/icn_t_yu.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48185'); return false;" title="신한글로벌액티브리츠"> 신한글로벌액티브리츠</a> </td>
#  <td class="textOverflow" title="신탁업 및 집합투자업">신탁업 및 집합투자업</td>
#  <td class="textOverflow" title="신탁 및 집합투자">신탁 및 집합투자</td>
#  <td class="txc">2024-07-01</td>
#  <td class="txc">02월</td>
#  <td class="txc" title="김선영">김선영</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://shglobalreit.com" target="_blank" title="http://shglobalreit.com"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)에이치브이엠"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('29531'); return false;" title="에이치브이엠"> 에이치브이엠</a> </td>
#  <td class="textOverflow" title="1차 비철금속 제조업">1차 비철금속 제조업</td>
#  <td class="textOverflow" title="Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등">Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등</td>
#  <td class="txc">2024-06-28</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="문승호">문승호</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://hvm.co.kr/" target="_blank" title="http://hvm.co.kr/"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">경기도</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)팡스카이"><img alt="코넥스" class="vmiddle legend" src="/images/common/icn_t_konex.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('26635'); return false;" title="팡스카이"> 팡스카이</a> </td>
#  <td class="textOverflow" title="소프트웨어 개발 및 공급업">소프트웨어 개발 및 공급업</td>
#  <td class="textOverflow" title="게임 개발 및 리퍼블리싱">게임 개발 및 리퍼블리싱</td>
#  <td class="txc">2024-06-28</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="조호현, 이병진">조호현..</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://www.panggame.com/" target="_blank" title="http://www.panggame.com/"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="하이젠알앤엠 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('16019'); return false;" title="하이젠알앤엠"> 하이젠알앤엠</a> </td>
#  <td class="textOverflow" title="전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업">전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업</td>
#  <td class="textOverflow" title="전동기 및 발전기 (범용모터, 서보모터)">전동기 및 발전기 (범용모터, 서보모터)</td>
#  <td class="txc">2024-06-27</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="김재학">김재학</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://higenrnm.com" target="_blank" title="http://higenrnm.com"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">경상남도</td>
#  </tr>,
#  <tr>
#  <td class="first" title="한국제15호기업인수목적 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47988'); return false;" title="한국제15호스팩"> 한국제15호스팩</a> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="기업인수합병">기업인수합병</td>
#  <td class="txc">2024-06-26</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="유한">유한</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="(주)에스오에스랩"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('46408'); return false;" title="에스오에스랩"> 에스오에스랩</a> </td>
#  <td class="textOverflow" title="측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외">측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외</td>
#  <td class="textOverflow" title="산업용 및 차량용 라이다(LiDAR)">산업용 및 차량용 라이다(LiDAR)</td>
#  <td class="txc">2024-06-25</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="정지성">정지성</td>
#  <td class="txc">
#  <a class="btn ico homepage" href="http://soslab.co" target="_blank" title="http://soslab.co"><span>홈페이지 보기</span></a>
#  </td>
#  <td class="txc">광주광역시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="미래에셋비전기업인수목적6호 주식회사"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47844'); return false;" title="미래에셋비전스팩6호"> 미래에셋비전스팩6호</a> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="기업인수합병">기업인수합병</td>
#  <td class="txc">2024-06-24</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="정명훈">정명훈</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>,
#  <tr>
#  <td class="first" title="에이치엠씨아이비제7호기업인수목적(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('47734'); return false;" title="에이치엠씨제7호스팩"> 에이치엠씨제7호스팩</a> </td>
#  <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
#  <td class="textOverflow" title="기타금융">기타금융</td>
#  <td class="txc">2024-06-24</td>
#  <td class="txc">12월</td>
#  <td class="txc" title="강신명">강신명</td>
#  <td class="txc">
#  </td>
#  <td class="txc">서울특별시</td>
#  </tr>]

# %%
soup.select('tr')[1]
# Out:
# <tr class="first">
# <td class="first" title="엔에이치기업인수목적31호(주)"><img alt="코스닥" class="vmiddle legend" src="/images/common/icn_t_ko.gif"/> <a href="#companysum" id="companysum" onclick="companysummary_open('48189'); return false;" title="엔에이치스팩31호"> 엔에이치스팩31호</a> </td>
# <td class="textOverflow" title="금융 지원 서비스업">금융 지원 서비스업</td>
# <td class="textOverflow" title="금융지원서비스업">금융지원서비스업</td>
# <td class="txc">2024-07-26</td>
# <td class="txc">12월</td>
# <td class="txc" title="이시형">이시형</td>
# <td class="txc">
# </td>
# <td class="txc">서울특별시</td>
# </tr>

# %%
total_items=int(soup.select_one(".info.type-00 > em").text.replace(",",""))
total_items
# Out:
# 2704

# %%
keys=soup.select_one("table.list.type-00.tmt30")['summary'].split(", ")
keys
# Out:
# ['회사명', '업종', '주요제품', '상장일', '결산월', '대표자명', '홈페이지', '지역']

# %%
result={}
for tr in soup.select('tr'):
    for key,td in zip(keys,(tr.select('td'))):
        result.setdefault(key,[]).append(td.text)
        
result_df=pd.DataFrame(result)
result_df
# Out:
#                회사명                                     업종  \
# 0       엔에이치스팩31호                              금융 지원 서비스업
# 1     SK증권제13호스팩                               금융 지원 서비스업
# 2         엑셀세라퓨틱스                             기초 의약물질 제조업
# 3        이베스트스팩6호                              금융 지원 서비스업
# 4            시프트업                          소프트웨어 개발 및 공급업
# 5              하스                   의료용품 및 기타 의약 관련제품 제조업
# 6          이노스페이스                        항공기,우주선 및 부품 제조업
# 7      신한글로벌액티브리츠                             신탁업 및 집합투자업
# 8          에이치브이엠                             1차 비철금속 제조업
# 9            팡스카이                          소프트웨어 개발 및 공급업
# 10         하이젠알앤엠       전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 11       한국제15호스팩                              금융 지원 서비스업
# 12         에스오에스랩   측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 13     미래에셋비전스팩6호                              금융 지원 서비스업
# 14     에이치엠씨제7호스팩                              금융 지원 서비스업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                            금융지원서비스업  2024-07-26  12월    이시형
# 1                                         기업인수목적 주식회사  2024-07-25  12월    임율표
# 2                              CellCor SFD/CD(세포배양배지)  2024-07-15  12월    이의일
# 3                                         기업인수목적 주식회사  2024-07-12  12월     박용
# 4                                            게임 소프트웨어  2024-07-11  12월    김형태
# 5   리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코...  2024-07-03  12월    김용수
# 6                         소형발사체, 로켓추진기관, 과학로켓, 시험평가용역  2024-07-02  12월    김수종
# 7                                           신탁 및 집합투자  2024-07-01  02월    김선영
# 8                    Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등  2024-06-28  12월    문승호
# 9                                       게임 개발 및 리퍼블리싱  2024-06-28  12월  조호현..
# 10                             전동기 및 발전기 (범용모터, 서보모터)  2024-06-27  12월    김재학
# 11                                             기업인수합병  2024-06-26  12월     유한
# 12                               산업용 및 차량용 라이다(LiDAR)  2024-06-25  12월    정지성
# 13                                             기업인수합병  2024-06-24  12월    정명훈
# 14                                               기타금융  2024-06-24  12월    강신명
#
#            홈페이지       지역
# 0            \n    서울특별시
# 1            \n    서울특별시
# 2            \n    서울특별시
# 3            \n    서울특별시
# 4   \n홈페이지 보기\n    서울특별시
# 5   \n홈페이지 보기\n  강원특별자치도
# 6   \n홈페이지 보기\n  세종특별자치시
# 7   \n홈페이지 보기\n    서울특별시
# 8   \n홈페이지 보기\n      경기도
# 9   \n홈페이지 보기\n    서울특별시
# 10  \n홈페이지 보기\n     경상남도
# 11           \n    서울특별시
# 12  \n홈페이지 보기\n    광주광역시
# 13           \n    서울특별시
# 14           \n    서울특별시

# %%
result={}
for tr in soup.select('tr'):
    for idx,(key,td) in enumerate( zip(keys,(tr.select('td')))):
        if idx==0:
            kinds = [img['alt'] for img in td.select('img')]
            kind = ", ".join(kinds)
            result.setdefault('증권종류', []).append(kind)
            result.setdefault(key,[]).append(td.text)
        elif idx==6:
            home_link=(td.select_one('a')['href'] if td.string==None else "")
            result.setdefault(key,[]).append(home_link)
        else:   
            result.setdefault(key,[]).append(td.text)
        

        

result_df=pd.DataFrame(result)
result_df
# Out:
#            증권종류             회사명                                     업종  \
# 0           코스닥      엔에이치스팩31호                              금융 지원 서비스업
# 1   코스닥, 투자주의종목    SK증권제13호스팩                               금융 지원 서비스업
# 2           코스닥        엑셀세라퓨틱스                             기초 의약물질 제조업
# 3           코스닥       이베스트스팩6호                              금융 지원 서비스업
# 4          유가증권           시프트업                          소프트웨어 개발 및 공급업
# 5           코스닥             하스                   의료용품 및 기타 의약 관련제품 제조업
# 6           코스닥         이노스페이스                        항공기,우주선 및 부품 제조업
# 7          유가증권     신한글로벌액티브리츠                             신탁업 및 집합투자업
# 8           코스닥         에이치브이엠                             1차 비철금속 제조업
# 9           코넥스           팡스카이                          소프트웨어 개발 및 공급업
# 10          코스닥         하이젠알앤엠       전동기, 발전기 및 전기 변환 · 공급 · 제어 장치 제조업
# 11          코스닥       한국제15호스팩                              금융 지원 서비스업
# 12          코스닥         에스오에스랩   측정, 시험, 항해, 제어 및 기타 정밀기기 제조업; 광학기기 제외
# 13          코스닥     미래에셋비전스팩6호                              금융 지원 서비스업
# 14          코스닥     에이치엠씨제7호스팩                              금융 지원 서비스업
#
#                                                  주요제품         상장일  결산월   대표자명  \
# 0                                            금융지원서비스업  2024-07-26  12월    이시형
# 1                                         기업인수목적 주식회사  2024-07-25  12월    임율표
# 2                              CellCor SFD/CD(세포배양배지)  2024-07-15  12월    이의일
# 3                                         기업인수목적 주식회사  2024-07-12  12월     박용
# 4                                            게임 소프트웨어  2024-07-11  12월    김형태
# 5   리튬디실리케이트 수복소재(Amber block, Amber Ingot 등), 지르코...  2024-07-03  12월    김용수
# 6                         소형발사체, 로켓추진기관, 과학로켓, 시험평가용역  2024-07-02  12월    김수종
# 7                                           신탁 및 집합투자  2024-07-01  02월    김선영
# 8                    Ni계 합금, Fe계 합금, 스퍼터링타겟, Cu계 합금 등  2024-06-28  12월    문승호
# 9                                       게임 개발 및 리퍼블리싱  2024-06-28  12월  조호현..
# 10                             전동기 및 발전기 (범용모터, 서보모터)  2024-06-27  12월    김재학
# 11                                             기업인수합병  2024-06-26  12월     유한
# 12                               산업용 및 차량용 라이다(LiDAR)  2024-06-25  12월    정지성
# 13                                             기업인수합병  2024-06-24  12월    정명훈
# 14                                               기타금융  2024-06-24  12월    강신명
#
#                         홈페이지       지역
# 0                               서울특별시
# 1                               서울특별시
# 2                               서울특별시
# 3                               서울특별시
# 4       http://shiftup.co.kr    서울특별시
# 5     http://www.hassbio.com  강원특별자치도
# 6    http://www.innospc.com/  세종특별자치시
# 7    http://shglobalreit.com    서울특별시
# 8          http://hvm.co.kr/      경기도
# 9   http://www.panggame.com/    서울특별시
# 10       http://higenrnm.com     경상남도
# 11                              서울특별시
# 12          http://soslab.co    광주광역시
# 13                              서울특별시
# 14                              서울특별시

# %%
page=1
page_size=100
final_result_df=pd.DataFrame()
while True:
    url="https://kind.krx.co.kr/corpgeneral/corpList.do"
    payload=dict(method='searchCorpList',pageIndex=1,currentPageSize=15,comAbbrv='',beginIndex='',orderMode=3,orderStat='D',isurCd='',repIsuSrtCd='',searchCodeType='',marketType='',searchType=13,industry='',fiscalYearEnd='all',comAbbrvTmp='',location='all')
    r=requests.get(url, params=payload)
    

    soup=bs(r.text,'lxml')
    total_items=int(soup.select_one(".info.type-00 > em").text.replace(",",""))
    total_pages=total_items//page_size +1
    print(f"{page}/{total_pages} 수집중", end="\r")
    
    result={}
    for tr in soup.select('tr'):
        for idx,(key,td) in enumerate( zip(keys,(tr.select('td')))):
            if idx==0:
                kinds = [img['alt'] for img in td.select('img')]
                kind = ", ".join(kinds)
                result.setdefault('증권종류', []).append(kind)
                result.setdefault(key,[]).append(td.text)
            elif idx==6:
                home_link=(td.select_one('a')['href'] if td.string==None else "")
                result.setdefault(key,[]).append(home_link)
            else:   
                result.setdefault(key,[]).append(td.text)
        

        

    result_df=pd.DataFrame(result)
    final_result_df=pd.concat([final_result_df,result_df])

    if page <total_pages:
        page+=1
        time.sleep(5)
    else:
        break
final_result_df
# Out:
# 16/28 수집중
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[271], line 7
#       5 url="https://kind.krx.co.kr/corpgeneral/corpList.do"
#       6 payload=dict(method='searchCorpList',pageIndex=1,currentPageSize=15,comAbbrv='',beginIndex='',orderMode=3,orderStat='D',isurCd='',repIsuSrtCd='',searchCodeType='',marketType='',searchType=13,industry='',fiscalYearEnd='all',comAbbrvTmp='',location='all')
# ----> 7 r=requests.get(url, params=payload)
#      10 soup=bs(r.text,'lxml')
#      11 total_items=int(soup.select_one(".info.type-00 > em").text.replace(",",""))
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\miniforge3\envs\fintech\lib\site-packages\requests\adapters.py:667, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     664     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     666 try:
# --> 667     resp = conn.urlopen(
#     668         method=request.method,
#     669         url=url,
#     670         body=request.body,
#     671         headers=request.headers,
#     672         redirect=False,
#     673         assert_same_host=False,
#     674         preload_content=False,
#     675         decode_content=False,
#     676         retries=self.max_retries,
#     677         timeout=timeout,
#     678         chunked=chunked,
#     679     )
#     681 except (ProtocolError, OSError) as err:
#     682     raise ConnectionError(err, request=request)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\miniforge3\envs\fintech\lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\miniforge3\envs\fintech\lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\miniforge3\envs\fintech\lib\http\client.py:1375, in HTTPConnection.getresponse(self)
#    1373 try:
#    1374     try:
# -> 1375         response.begin()
#    1376     except ConnectionError:
#    1377         self.close()
#
# File ~\miniforge3\envs\fintech\lib\http\client.py:318, in HTTPResponse.begin(self)
#     316 # read until we get a non-100 response
#     317 while True:
# --> 318     version, status, reason = self._read_status()
#     319     if status != CONTINUE:
#     320         break
#
# File ~\miniforge3\envs\fintech\lib\http\client.py:279, in HTTPResponse._read_status(self)
#     278 def _read_status(self):
# --> 279     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     280     if len(line) > _MAXLINE:
#     281         raise LineTooLong("status line")
#
# File ~\miniforge3\envs\fintech\lib\socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# File ~\miniforge3\envs\fintech\lib\ssl.py:1307, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1303     if flags != 0:
#    1304         raise ValueError(
#    1305           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1306           self.__class__)
# -> 1307     return self.read(nbytes, buffer)
#    1308 else:
#    1309     return super().recv_into(buffer, nbytes, flags)
#
# File ~\miniforge3\envs\fintech\lib\ssl.py:1163, in SSLSocket.read(self, len, buffer)
#    1161 try:
#    1162     if buffer is not None:
# -> 1163         return self._sslobj.read(len, buffer)
#    1164     else:
#    1165         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
soup.select_one("#currentPageSize ")
# Out:
# <select id="currentPageSize" name="currentPageSize">
# <option selected="selected" value="15">15건</option>
# <option value="30">30건</option>
# <option value="50">50건</option>
# <option value="100">100건</option>
# </select>
